# %% [markdown]
# #### Import libraries

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import numpy as np

import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score

# %% [markdown]
# #### Import dataframe

# %%
df = pd.read_csv('all_music_data.csv')
df
# Out:
#       Unnamed: 0                      song_title           artist  \
# 0              0                         Hey Ya!          Outkast
# 1              1                No Woman, No Cry           Fugees
# 2              2                 Can You Feel It     The Jacksons
# 3              3                         Foolish          Ashanti
# 4              4               Arigato Interlude  Ms. Lauryn Hill
# ...          ...                             ...              ...
# 7312        7312                              XO       John Mayer
# 7313        7313               Un-Break My Heart     Toni Braxton
# 7314        7314                     God Is a DJ        Faithless
# 7315        7315  I Wanna Be Adored - Remastered  The Stone Roses
# 7316        7316                       Adore You      Miley Cyrus
#
#                           id  danceability  energy  key  loudness  mode  \
# 0     0JFx4l1JZJ6XtMAtlCMiqF         0.657   0.883    4    -6.778     0
# 1     5bUVHuzQh5mkvMPjUU074i         0.846   0.326    0   -13.909     1
# 2     1XqgxhR3FcJXzFiSG8m6oL         0.892   0.638    6    -7.468     0
# 3     5wXgj9h0Pc36Rcgwf2qd7A         0.620   0.701    0    -5.742     1
# 4     3abz5HTatP9iv5p8Nm5IT0         0.000   0.978   10    -9.615     1
# ...                      ...           ...     ...  ...       ...   ...
# 7312  0hm785gGfLmHvl9YesZcFP         0.431   0.377    2    -9.753     1
# 7313  5CYbKUBECU71XChJBP01KE         0.620   0.417   11    -9.166     0
# 7314  76QhWAnwj7aSgAYPOPNXYN         0.604   0.893   10    -7.480     0
# 7315  5vnMGVPld0mhqVVHMK89y3         0.502   0.860    4    -9.251     0
# 7316  0N3VOIfkk1Ha2UJiVdeo32         0.552   0.579    0    -7.745     1
#
#       speechiness  ...  instrumentalness  liveness  valence    tempo  \
# 0          0.0526  ...          0.000000    0.3060    0.966   79.397
# 1          0.1520  ...          0.000040    0.2800    0.367   88.988
# 2          0.0488  ...          0.000476    0.2020    0.892  125.359
# 3          0.0624  ...          0.000000    0.1470    0.771   90.059
# 4          0.0000  ...          0.002280    0.9510    0.000    0.000
# ...           ...  ...               ...       ...      ...      ...
# 7312       0.0288  ...          0.000000    0.2110    0.353  173.670
# 7313       0.0286  ...          0.000000    0.0984    0.133  109.904
# 7314       0.0453  ...          0.900000    0.1570    0.366  130.555
# 7315       0.0278  ...          0.240000    0.2160    0.559  112.585
# 7316       0.0332  ...          0.000003    0.1910    0.220  119.748
#
#                 type                                   uri  \
# 0     audio_features  spotify:track:0JFx4l1JZJ6XtMAtlCMiqF
# 1     audio_features  spotify:track:5bUVHuzQh5mkvMPjUU074i
# 2     audio_features  spotify:track:1XqgxhR3FcJXzFiSG8m6oL
# 3     audio_features  spotify:track:5wXgj9h0Pc36Rcgwf2qd7A
# 4     audio_features  spotify:track:3abz5HTatP9iv5p8Nm5IT0
# ...              ...                                   ...
# 7312  audio_features  spotify:track:0hm785gGfLmHvl9YesZcFP
# 7313  audio_features  spotify:track:5CYbKUBECU71XChJBP01KE
# 7314  audio_features  spotify:track:76QhWAnwj7aSgAYPOPNXYN
# 7315  audio_features  spotify:track:5vnMGVPld0mhqVVHMK89y3
# 7316  audio_features  spotify:track:0N3VOIfkk1Ha2UJiVdeo32
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0JFx4l1JZJ6X...
# 1     https://api.spotify.com/v1/tracks/5bUVHuzQh5mk...
# 2     https://api.spotify.com/v1/tracks/1XqgxhR3FcJX...
# 3     https://api.spotify.com/v1/tracks/5wXgj9h0Pc36...
# 4     https://api.spotify.com/v1/tracks/3abz5HTatP9i...
# ...                                                 ...
# 7312  https://api.spotify.com/v1/tracks/0hm785gGfLmH...
# 7313  https://api.spotify.com/v1/tracks/5CYbKUBECU71...
# 7314  https://api.spotify.com/v1/tracks/76QhWAnwj7aS...
# 7315  https://api.spotify.com/v1/tracks/5vnMGVPld0mh...
# 7316  https://api.spotify.com/v1/tracks/0N3VOIfkk1Ha...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0JFx...      228573
# 1     https://api.spotify.com/v1/audio-analysis/5bUV...      273093
# 2     https://api.spotify.com/v1/audio-analysis/1Xqg...      358373
# 3     https://api.spotify.com/v1/audio-analysis/5wXg...      229013
# 4     https://api.spotify.com/v1/audio-analysis/3abz...       34182
# ...                                                 ...         ...
# 7312  https://api.spotify.com/v1/audio-analysis/0hm7...      213627
# 7313  https://api.spotify.com/v1/audio-analysis/5CYb...      271467
# 7314  https://api.spotify.com/v1/audio-analysis/76Qh...      207613
# 7315  https://api.spotify.com/v1/audio-analysis/5vnM...      292413
# 7316  https://api.spotify.com/v1/audio-analysis/0N3V...      277760
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  0
# ...              ...
# 7312               4
# 7313               4
# 7314               4
# 7315               4
# 7316               4
#
# [7317 rows x 21 columns]

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df
# Out:
#                           song_title           artist                      id  \
# 0                            Hey Ya!          Outkast  0JFx4l1JZJ6XtMAtlCMiqF
# 1                   No Woman, No Cry           Fugees  5bUVHuzQh5mkvMPjUU074i
# 2                    Can You Feel It     The Jacksons  1XqgxhR3FcJXzFiSG8m6oL
# 3                            Foolish          Ashanti  5wXgj9h0Pc36Rcgwf2qd7A
# 4                  Arigato Interlude  Ms. Lauryn Hill  3abz5HTatP9iv5p8Nm5IT0
# ...                              ...              ...                     ...
# 7312                              XO       John Mayer  0hm785gGfLmHvl9YesZcFP
# 7313               Un-Break My Heart     Toni Braxton  5CYbKUBECU71XChJBP01KE
# 7314                     God Is a DJ        Faithless  76QhWAnwj7aSgAYPOPNXYN
# 7315  I Wanna Be Adored - Remastered  The Stone Roses  5vnMGVPld0mhqVVHMK89y3
# 7316                       Adore You      Miley Cyrus  0N3VOIfkk1Ha2UJiVdeo32
#
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.657   0.883    4    -6.778     0       0.0526        0.0349
# 1            0.846   0.326    0   -13.909     1       0.1520        0.0134
# 2            0.892   0.638    6    -7.468     0       0.0488        0.0445
# 3            0.620   0.701    0    -5.742     1       0.0624        0.3160
# 4            0.000   0.978   10    -9.615     1       0.0000        0.7990
# ...            ...     ...  ...       ...   ...          ...           ...
# 7312         0.431   0.377    2    -9.753     1       0.0288        0.7490
# 7313         0.620   0.417   11    -9.166     0       0.0286        0.4150
# 7314         0.604   0.893   10    -7.480     0       0.0453        0.1750
# 7315         0.502   0.860    4    -9.251     0       0.0278        0.0123
# 7316         0.552   0.579    0    -7.745     1       0.0332        0.1110
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.000000    0.3060    0.966   79.397  audio_features
# 1             0.000040    0.2800    0.367   88.988  audio_features
# 2             0.000476    0.2020    0.892  125.359  audio_features
# 3             0.000000    0.1470    0.771   90.059  audio_features
# 4             0.002280    0.9510    0.000    0.000  audio_features
# ...                ...       ...      ...      ...             ...
# 7312          0.000000    0.2110    0.353  173.670  audio_features
# 7313          0.000000    0.0984    0.133  109.904  audio_features
# 7314          0.900000    0.1570    0.366  130.555  audio_features
# 7315          0.240000    0.2160    0.559  112.585  audio_features
# 7316          0.000003    0.1910    0.220  119.748  audio_features
#
#                                        uri  \
# 0     spotify:track:0JFx4l1JZJ6XtMAtlCMiqF
# 1     spotify:track:5bUVHuzQh5mkvMPjUU074i
# 2     spotify:track:1XqgxhR3FcJXzFiSG8m6oL
# 3     spotify:track:5wXgj9h0Pc36Rcgwf2qd7A
# 4     spotify:track:3abz5HTatP9iv5p8Nm5IT0
# ...                                    ...
# 7312  spotify:track:0hm785gGfLmHvl9YesZcFP
# 7313  spotify:track:5CYbKUBECU71XChJBP01KE
# 7314  spotify:track:76QhWAnwj7aSgAYPOPNXYN
# 7315  spotify:track:5vnMGVPld0mhqVVHMK89y3
# 7316  spotify:track:0N3VOIfkk1Ha2UJiVdeo32
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/0JFx4l1JZJ6X...
# 1     https://api.spotify.com/v1/tracks/5bUVHuzQh5mk...
# 2     https://api.spotify.com/v1/tracks/1XqgxhR3FcJX...
# 3     https://api.spotify.com/v1/tracks/5wXgj9h0Pc36...
# 4     https://api.spotify.com/v1/tracks/3abz5HTatP9i...
# ...                                                 ...
# 7312  https://api.spotify.com/v1/tracks/0hm785gGfLmH...
# 7313  https://api.spotify.com/v1/tracks/5CYbKUBECU71...
# 7314  https://api.spotify.com/v1/tracks/76QhWAnwj7aS...
# 7315  https://api.spotify.com/v1/tracks/5vnMGVPld0mh...
# 7316  https://api.spotify.com/v1/tracks/0N3VOIfkk1Ha...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/0JFx...       228573
# 1     https://api.spotify.com/v1/audio-analysis/5bUV...       273093
# 2     https://api.spotify.com/v1/audio-analysis/1Xqg...       358373
# 3     https://api.spotify.com/v1/audio-analysis/5wXg...       229013
# 4     https://api.spotify.com/v1/audio-analysis/3abz...        34182
# ...                                                 ...          ...
# 7312  https://api.spotify.com/v1/audio-analysis/0hm7...       213627
# 7313  https://api.spotify.com/v1/audio-analysis/5CYb...       271467
# 7314  https://api.spotify.com/v1/audio-analysis/76Qh...       207613
# 7315  https://api.spotify.com/v1/audio-analysis/5vnM...       292413
# 7316  https://api.spotify.com/v1/audio-analysis/0N3V...       277760
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  0
# ...              ...
# 7312               4
# 7313               4
# 7314               4
# 7315               4
# 7316               4
#
# [7317 rows x 20 columns]

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.shape
# Out:
# (7317, 20)

# %% [markdown]
# #### Categorical and Numerical

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7317 entries, 0 to 7316
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_title        7317 non-null   object
#  1   artist            7317 non-null   object
#  2   id                7317 non-null   object
#  3   danceability      7317 non-null   float64
#  4   energy            7317 non-null   float64
#  5   key               7317 non-null   int64
#  6   loudness          7317 non-null   float64
#  7   mode              7317 non-null   int64
#  8   speechiness       7317 non-null   float64
#  9   acousticness      7317 non-null   float64
#  10  instrumentalness  7317 non-null   float64
#  11  liveness          7317 non-null   float64
#  12  valence           7317 non-null   float64
#  13  tempo             7317 non-null   float64
#  14  type              7317 non-null   object
#  15  uri               7317 non-null   object
#  16  track_href        7317 non-null   object
#  17  analysis_url      7317 non-null   object
#  18  duration_ms       7317 non-null   int64
#  19  time_signature    7317 non-null   int64
# dtypes: float64(9), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
df_fl = df.select_dtypes("float64")

# %%
df_fl
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 0            0.657   0.883    -6.778       0.0526        0.0349
# 1            0.846   0.326   -13.909       0.1520        0.0134
# 2            0.892   0.638    -7.468       0.0488        0.0445
# 3            0.620   0.701    -5.742       0.0624        0.3160
# 4            0.000   0.978    -9.615       0.0000        0.7990
# ...            ...     ...       ...          ...           ...
# 7312         0.431   0.377    -9.753       0.0288        0.7490
# 7313         0.620   0.417    -9.166       0.0286        0.4150
# 7314         0.604   0.893    -7.480       0.0453        0.1750
# 7315         0.502   0.860    -9.251       0.0278        0.0123
# 7316         0.552   0.579    -7.745       0.0332        0.1110
#
#       instrumentalness  liveness  valence    tempo
# 0             0.000000    0.3060    0.966   79.397
# 1             0.000040    0.2800    0.367   88.988
# 2             0.000476    0.2020    0.892  125.359
# 3             0.000000    0.1470    0.771   90.059
# 4             0.002280    0.9510    0.000    0.000
# ...                ...       ...      ...      ...
# 7312          0.000000    0.2110    0.353  173.670
# 7313          0.000000    0.0984    0.133  109.904
# 7314          0.900000    0.1570    0.366  130.555
# 7315          0.240000    0.2160    0.559  112.585
# 7316          0.000003    0.1910    0.220  119.748
#
# [7317 rows x 9 columns]

# %%
df_af =

# %%
df_int = df.select_dtypes("int64")

# %%
df_int
# Out:
#       key  mode  duration_ms  time_signature
# 0       4     0       228573               4
# 1       0     1       273093               4
# 2       6     0       358373               4
# 3       0     1       229013               4
# 4      10     1        34182               0
# ...   ...   ...          ...             ...
# 7312    2     1       213627               4
# 7313   11     0       271467               4
# 7314   10     0       207613               4
# 7315    4     0       292413               4
# 7316    0     1       277760               4
#
# [7317 rows x 4 columns]

# %%
df_num = pd.concat(['df_fl', 'df_int'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_7660/1496588221.py in <module>
# ----> 1 df_num = pd.concat(['df_fl', 'df_int'], axis=1)
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     382                     "only Series and DataFrame objs are valid"
#     383                 )
# --> 384                 raise TypeError(msg)
#     385
#     386             ndims.add(obj.ndim)
#
# TypeError: cannot concatenate object of type '<class 'str'>'; only Series and DataFrame objs are valid

# %%
df.describe()
# Out:
#        danceability       energy          key     loudness         mode  \
# count   7317.000000  7317.000000  7317.000000  7317.000000  7317.000000
# mean       0.587391     0.607030     5.295476    -8.326448     0.634960
# std        0.168777     0.221907     3.588778     3.553579     0.481474
# min        0.000000     0.001140     0.000000   -40.230000     0.000000
# 25%        0.473000     0.462000     2.000000    -9.753000     0.000000
# 50%        0.602000     0.628000     5.000000    -7.727000     1.000000
# 75%        0.714000     0.784000     8.000000    -6.077000     1.000000
# max        0.969000     0.998000    11.000000    -1.492000     1.000000
#
#        speechiness  acousticness  instrumentalness     liveness      valence  \
# count  7317.000000   7317.000000       7317.000000  7317.000000  7317.000000
# mean      0.091835      0.285053          0.044119     0.208400     0.533108
# std       0.111609      0.300661          0.161981     0.181537     0.253073
# min       0.000000      0.000008          0.000000     0.015700     0.000000
# 25%       0.033100      0.039300          0.000000     0.096200     0.328000
# 50%       0.044700      0.156000          0.000008     0.134000     0.549000
# 75%       0.091200      0.469000          0.000716     0.268000     0.739000
# max       0.948000      0.996000          0.964000     0.994000     0.985000
#
#              tempo   duration_ms  time_signature
# count  7317.000000  7.317000e+03     7317.000000
# mean    114.581336  2.428530e+05        3.913489
# std      29.171158  9.051329e+04        0.399945
# min       0.000000  8.867000e+03        0.000000
# 25%      93.010000  2.049470e+05        4.000000
# 50%     108.873000  2.376530e+05        4.000000
# 75%     130.618000  2.692670e+05        4.000000
# max     216.160000  4.650486e+06        5.000000

# %%
#key, loudness, tempo, duration
#we need to scale

# %% [markdown]
# #### Scaling

# %%
scaler = StandardScaler()
scaler.fit(df)
df_scaled = scaler.transform(df)
df_scaled_df = pd.DataFrame(df_scaled, columns = df.columns)
display(df.head())
print()
display(df_scaled_df.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mm/gw92vpys6rggjz_4z42s244w0000gn/T/ipykernel_7660/3403469043.py in <module>
#       1 scaler = StandardScaler()
# ----> 2 scaler.fit(df)
#       3 df_scaled = scaler.transform(df)
#       4 df_scaled_df = pd.DataFrame(df_scaled, columns = df.columns)
#       5 display(df.head())
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
#     732     def partial_fit(self, X, y=None, sample_weight=None):
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y, sample_weight)
#     764         """
#     765         first_call = not hasattr(self, "n_samples_seen_")
# --> 766         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     767                                 estimator=self, dtype=FLOAT_DTYPES,
#     768                                 force_all_finite='allow-nan', reset=first_call)
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     419             out = X
#     420         elif isinstance(y, str) and y == 'no_validation':
# --> 421             X = check_array(X, **check_params)
#     422             out = X
#     423         else:
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     671                     array = array.astype(dtype, casting="unsafe", copy=False)
#     672                 else:
# --> 673                     array = np.asarray(array, order=order, dtype=dtype)
#     674             except ComplexWarning as complex_warning:
#     675                 raise ValueError("Complex data not supported\n"
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# /opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ValueError: could not convert string to float: 'Hey Ya!'
