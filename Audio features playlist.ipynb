# %% [markdown]
# ### Load config

# %%
import config

# %% [markdown]
# ### Start with spotify API

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.c_id,
                                                           client_secret= config.c_se))

# %%
results = sp.search(q="AA",limit=1,market="GB")
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=AA&type=track&market=GB&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'},
#        'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N',
#        'id': '4aXXDj9aZnlshx7mzj3W1N',
#        'name': 'Lin-Manuel Miranda',
#        'type': 'artist',
#        'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1kCHru7uhxBUdzkm4gzRQc'},
#      'href': 'https://api.spotify.com/v1/albums/1kCHru7uhxBUdzkm4gzRQc',
#      'id': '1kCHru7uhxBUdzkm4gzRQc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d72fb5571087bca0a2fed008',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d72fb5571087bca0a2fed008',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d72fb5571087bca0a2fed008',
#        'width': 64}],
#      'name': 'Hamilton (Original Broadway Cast Recording)',
#      'release_date': '2015-09-25',
#      'release_date_precision': 'day',
#      'total_tracks': 46,
#      'type': 'album',
#      'uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'},
#       'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N',
#       'id': '4aXXDj9aZnlshx7mzj3W1N',
#       'name': 'Lin-Manuel Miranda',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3cR4rhS2hBWqI7rJEBacvN'},
#       'href': 'https://api.spotify.com/v1/artists/3cR4rhS2hBWqI7rJEBacvN',
#       'id': '3cR4rhS2hBWqI7rJEBacvN',
#       'name': 'Leslie Odom Jr.',
#       'type': 'artist',
#       'uri': 'spotify:artist:3cR4rhS2hBWqI7rJEBacvN'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/660YptcR0hNHJ8iEr1qcse'},
#       'href': 'https://api.spotify.com/v1/artists/660YptcR0hNHJ8iEr1qcse',
#       'id': '660YptcR0hNHJ8iEr1qcse',
#       'name': 'Anthony Ramos',
#       'type': 'artist',
#       'uri': 'spotify:artist:660YptcR0hNHJ8iEr1qcse'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3twuAojvYNrlWZpMkxLm3P'},
#       'href': 'https://api.spotify.com/v1/artists/3twuAojvYNrlWZpMkxLm3P',
#       'id': '3twuAojvYNrlWZpMkxLm3P',
#       'name': 'Daveed Diggs',
#       'type': 'artist',
#       'uri': 'spotify:artist:3twuAojvYNrlWZpMkxLm3P'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6G3sPhnj4JBCsBVBGvZnkk'},
#       'href': 'https://api.spotify.com/v1/artists/6G3sPhnj4JBCsBVBGvZnkk',
#       'id': '6G3sPhnj4JBCsBVBGvZnkk',
#       'name': 'Okieriete Onaodowan',
#       'type': 'artist',
#       'uri': 'spotify:artist:6G3sPhnj4JBCsBVBGvZnkk'}],
#     'disc_number': 1,
#     'duration_ms': 156630,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21502597'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6dr7ekfhlbquvsVY8D7gyk'},
#     'href': 'https://api.spotify.com/v1/tracks/6dr7ekfhlbquvsVY8D7gyk',
#     'id': '6dr7ekfhlbquvsVY8D7gyk',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Aaron Burr, Sir',
#     'popularity': 71,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a693bdbcde80bd0c4e9c3ee6078a30402533f202?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6dr7ekfhlbquvsVY8D7gyk'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=AA&type=track&market=GB&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 10031}}

# %% [markdown]
# ### Navigating through dictionary

# %%
track_id=results['tracks']['items'][0]['external_urls']["spotify"][31:]
track_id
# Out:
# '6dr7ekfhlbquvsVY8D7gyk'

# %% [markdown]
# #### Embedded Track Players

# %%
from IPython.display import IFrame

#track_id = "1rfORa9iYmocEsnnZGMVC4"

IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/6dr7ekfhlbquvsVY8D7gyk?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=AA&type=track&market=GB&offset=0&limit=1',
#             'items': [{'album': {'album_type': 'album',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'},
#                                               'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N',
#                                               'id': '4aXXDj9aZnlshx7mzj3W1N',
#                                               'name': 'Lin-Manuel Miranda',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1kCHru7uhxBUdzkm4gzRQc'},
#                                  'href': 'https://api.spotify.com/v1/albums/1kCHru7uhxBUdzkm4gzRQc',
#                                  'id': '1kCHru7uhxBUdzkm4gzRQc',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273d72fb5571087bca0a2fed008',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02d72fb5571087bca0a2fed008',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851d72fb5571087bca0a2fed008',
#                                              'width': 64}],
#                                  'name': 'Hamilton (Original Broadway Cast '
#                                          'Recording)',
#                                  'release_date': '2015-09-25',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 46,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'},
#                                     'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N',
#                                     'id': '4aXXDj9aZnlshx7mzj3W1N',
#                                     'name': 'Lin-Manuel Miranda',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3cR4rhS2hBWqI7rJEBacvN'},
#                                     'href': 'https://api.spotify.com/v1/artists/3cR4rhS2hBWqI7rJEBacvN',
#                                     'id': '3cR4rhS2hBWqI7rJEBacvN',
#                                     'name': 'Leslie Odom Jr.',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3cR4rhS2hBWqI7rJEBacvN'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/660YptcR0hNHJ8iEr1qcse'},
#                                     'href': 'https://api.spotify.com/v1/artists/660YptcR0hNHJ8iEr1qcse',
#                                     'id': '660YptcR0hNHJ8iEr1qcse',
#                                     'name': 'Anthony Ramos',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:660YptcR0hNHJ8iEr1qcse'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3twuAojvYNrlWZpMkxLm3P'},
#                                     'href': 'https://api.spotify.com/v1/artists/3twuAojvYNrlWZpMkxLm3P',
#                                     'id': '3twuAojvYNrlWZpMkxLm3P',
#                                     'name': 'Daveed Diggs',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:3twuAojvYNrlWZpMkxLm3P'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/6G3sPhnj4JBCsBVBGvZnkk'},
#                                     'href': 'https://api.spotify.com/v1/artists/6G3sPhnj4JBCsBVBGvZnkk',
#                                     'id': '6G3sPhnj4JBCsBVBGvZnkk',
#                                     'name': 'Okieriete Onaodowan',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6G3sPhnj4JBCsBVBGvZnkk'}],
#                        'disc_number': 1,
#                        'duration_ms': 156630,
#                        'explicit': False,
#                        'external_ids': {'isrc': 'USAT21502597'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/6dr7ekfhlbquvsVY8D7gyk'},
#                        'href': 'https://api.spotify.com/v1/tracks/6dr7ekfhlbquvsVY8D7gyk',
#                        'id': '6dr7ekfhlbquvsVY8D7gyk',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Aaron Burr, Sir',
#                        'popularity': 71,
#                        'preview_url': 'https://p.scdn.co/mp3-preview/a693bdbcde80bd0c4e9c3ee6078a30402533f202?cid=acf6602caa5749f79900cabb94c1c3e4',
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:6dr7ekfhlbquvsVY8D7gyk'}],
#             'limit': 1,
#             'next': 'https://api.spotify.com/v1/search?query=AA&type=track&market=GB&offset=1&limit=1',
#             'offset': 0,
#             'previous': None,
#             'total': 10031}}

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'},
#     'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N',
#     'id': '4aXXDj9aZnlshx7mzj3W1N',
#     'name': 'Lin-Manuel Miranda',
#     'type': 'artist',
#     'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1kCHru7uhxBUdzkm4gzRQc'},
#   'href': 'https://api.spotify.com/v1/albums/1kCHru7uhxBUdzkm4gzRQc',
#   'id': '1kCHru7uhxBUdzkm4gzRQc',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273d72fb5571087bca0a2fed008',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02d72fb5571087bca0a2fed008',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851d72fb5571087bca0a2fed008',
#     'width': 64}],
#   'name': 'Hamilton (Original Broadway Cast Recording)',
#   'release_date': '2015-09-25',
#   'release_date_precision': 'day',
#   'total_tracks': 46,
#   'type': 'album',
#   'uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'},
#    'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N',
#    'id': '4aXXDj9aZnlshx7mzj3W1N',
#    'name': 'Lin-Manuel Miranda',
#    'type': 'artist',
#    'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3cR4rhS2hBWqI7rJEBacvN'},
#    'href': 'https://api.spotify.com/v1/artists/3cR4rhS2hBWqI7rJEBacvN',
#    'id': '3cR4rhS2hBWqI7rJEBacvN',
#    'name': 'Leslie Odom Jr.',
#    'type': 'artist',
#    'uri': 'spotify:artist:3cR4rhS2hBWqI7rJEBacvN'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/660YptcR0hNHJ8iEr1qcse'},
#    'href': 'https://api.spotify.com/v1/artists/660YptcR0hNHJ8iEr1qcse',
#    'id': '660YptcR0hNHJ8iEr1qcse',
#    'name': 'Anthony Ramos',
#    'type': 'artist',
#    'uri': 'spotify:artist:660YptcR0hNHJ8iEr1qcse'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3twuAojvYNrlWZpMkxLm3P'},
#    'href': 'https://api.spotify.com/v1/artists/3twuAojvYNrlWZpMkxLm3P',
#    'id': '3twuAojvYNrlWZpMkxLm3P',
#    'name': 'Daveed Diggs',
#    'type': 'artist',
#    'uri': 'spotify:artist:3twuAojvYNrlWZpMkxLm3P'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/6G3sPhnj4JBCsBVBGvZnkk'},
#    'href': 'https://api.spotify.com/v1/artists/6G3sPhnj4JBCsBVBGvZnkk',
#    'id': '6G3sPhnj4JBCsBVBGvZnkk',
#    'name': 'Okieriete Onaodowan',
#    'type': 'artist',
#    'uri': 'spotify:artist:6G3sPhnj4JBCsBVBGvZnkk'}],
#  'disc_number': 1,
#  'duration_ms': 156630,
#  'explicit': False,
#  'external_ids': {'isrc': 'USAT21502597'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6dr7ekfhlbquvsVY8D7gyk'},
#  'href': 'https://api.spotify.com/v1/tracks/6dr7ekfhlbquvsVY8D7gyk',
#  'id': '6dr7ekfhlbquvsVY8D7gyk',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Aaron Burr, Sir',
#  'popularity': 71,
#  'preview_url': 'https://p.scdn.co/mp3-preview/a693bdbcde80bd0c4e9c3ee6078a30402533f202?cid=acf6602caa5749f79900cabb94c1c3e4',
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:6dr7ekfhlbquvsVY8D7gyk'}

# %% [markdown]
# #### getting the track id

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results['tracks']['items'][0]['id']
# Out:
# '6dr7ekfhlbquvsVY8D7gyk'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item['external_urls']['spotify']))
# Out:
# The name of song is: 'Aaron Burr, Sir' and the id is: https://open.spotify.com/track/6dr7ekfhlbquvsVY8D7gyk

# %%
song = sp.search(q="Bad Guy", limit=50,market="GB") 
song
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Bad+Guy&type=track&market=GB&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#      'href': 'https://api.spotify.com/v1/albums/0S0KGZnfBGSIssfF54WSJh',
#      'id': '0S0KGZnfBGSIssfF54WSJh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27350a3147b4edd7701a876c6ce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0250a3147b4edd7701a876c6ce',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485150a3147b4edd7701a876c6ce',
#        'width': 64}],
#      'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#      'release_date': '2019-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0S0KGZnfBGSIssfF54WSJh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 194087,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Fxmhks0bxGSBdJ92vM42m'},
#     'href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#     'id': '2Fxmhks0bxGSBdJ92vM42m',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 87,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5mgQtxR15wa4x3sOQwiqls'},
#        'href': 'https://api.spotify.com/v1/artists/5mgQtxR15wa4x3sOQwiqls',
#        'id': '5mgQtxR15wa4x3sOQwiqls',
#        'name': 'grande1899',
#        'type': 'artist',
#        'uri': 'spotify:artist:5mgQtxR15wa4x3sOQwiqls'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4q9uNVJZWv2Tp4lLODNiI3'},
#      'href': 'https://api.spotify.com/v1/albums/4q9uNVJZWv2Tp4lLODNiI3',
#      'id': '4q9uNVJZWv2Tp4lLODNiI3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732d57c492127a4694cfb8c866',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022d57c492127a4694cfb8c866',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512d57c492127a4694cfb8c866',
#        'width': 64}],
#      'name': 'Bad Guy (Minecraft Note Blocks)',
#      'release_date': '2019-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4q9uNVJZWv2Tp4lLODNiI3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5mgQtxR15wa4x3sOQwiqls'},
#       'href': 'https://api.spotify.com/v1/artists/5mgQtxR15wa4x3sOQwiqls',
#       'id': '5mgQtxR15wa4x3sOQwiqls',
#       'name': 'grande1899',
#       'type': 'artist',
#       'uri': 'spotify:artist:5mgQtxR15wa4x3sOQwiqls'}],
#     'disc_number': 1,
#     'duration_ms': 149453,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZGWW1953686'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ktuJSnA0K4YwRZOKYCWl6'},
#     'href': 'https://api.spotify.com/v1/tracks/2ktuJSnA0K4YwRZOKYCWl6',
#     'id': '2ktuJSnA0K4YwRZOKYCWl6',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (Minecraft Note Blocks)',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4660bc4af531e317d357b375ebe23a10800bb2e4?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2ktuJSnA0K4YwRZOKYCWl6'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6DN7GcZF1HywzrkGN6Eeqk'},
#      'href': 'https://api.spotify.com/v1/albums/6DN7GcZF1HywzrkGN6Eeqk',
#      'id': '6DN7GcZF1HywzrkGN6Eeqk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cb66bcc14c6f857c127d5969',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cb66bcc14c6f857c127d5969',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cb66bcc14c6f857c127d5969',
#        'width': 64}],
#      'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:6DN7GcZF1HywzrkGN6Eeqk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 434077,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71314073'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3IaAYtmN8T0YIYVqnxNnVz'},
#     'href': 'https://api.spotify.com/v1/tracks/3IaAYtmN8T0YIYVqnxNnVz',
#     'id': '3IaAYtmN8T0YIYVqnxNnVz',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3IaAYtmN8T0YIYVqnxNnVz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3iMZi6l2502goK32DZW3KM'},
#      'href': 'https://api.spotify.com/v1/albums/3iMZi6l2502goK32DZW3KM',
#      'id': '3iMZi6l2502goK32DZW3KM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732b387540043b47ef37ed56d0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022b387540043b47ef37ed56d0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512b387540043b47ef37ed56d0',
#        'width': 64}],
#      'name': 'Women in Pop 2022',
#      'release_date': '2022-02-16',
#      'release_date_precision': 'day',
#      'total_tracks': 26,
#      'type': 'album',
#      'uri': 'spotify:album:3iMZi6l2502goK32DZW3KM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 194087,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6Pb9sdCx4rEl9ynAysZdMP'},
#     'href': 'https://api.spotify.com/v1/tracks/6Pb9sdCx4rEl9ynAysZdMP',
#     'id': '6Pb9sdCx4rEl9ynAysZdMP',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 0,
#     'preview_url': None,
#     'track_number': 26,
#     'type': 'track',
#     'uri': 'spotify:track:6Pb9sdCx4rEl9ynAysZdMP'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25Maank76ry2Tmbi2Ql1SF'},
#        'href': 'https://api.spotify.com/v1/artists/25Maank76ry2Tmbi2Ql1SF',
#        'id': '25Maank76ry2Tmbi2Ql1SF',
#        'name': 'The Interrupters',
#        'type': 'artist',
#        'uri': 'spotify:artist:25Maank76ry2Tmbi2Ql1SF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2oU2YsoVW3KG0jIlDXWIkx'},
#      'href': 'https://api.spotify.com/v1/albums/2oU2YsoVW3KG0jIlDXWIkx',
#      'id': '2oU2YsoVW3KG0jIlDXWIkx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a33fad32ad43b17010154e0a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a33fad32ad43b17010154e0a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a33fad32ad43b17010154e0a',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2019-10-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2oU2YsoVW3KG0jIlDXWIkx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25Maank76ry2Tmbi2Ql1SF'},
#       'href': 'https://api.spotify.com/v1/artists/25Maank76ry2Tmbi2Ql1SF',
#       'id': '25Maank76ry2Tmbi2Ql1SF',
#       'name': 'The Interrupters',
#       'type': 'artist',
#       'uri': 'spotify:artist:25Maank76ry2Tmbi2Ql1SF'}],
#     'disc_number': 1,
#     'duration_ms': 157831,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHEL1901003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0iM1Ioz4N4p7MU1DKyqsov'},
#     'href': 'https://api.spotify.com/v1/tracks/0iM1Ioz4N4p7MU1DKyqsov',
#     'id': '0iM1Ioz4N4p7MU1DKyqsov',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/44868812d90a3a45ad37c5ca5337d1b3f81ea790?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0iM1Ioz4N4p7MU1DKyqsov'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6lMlX68jJrx67hiCqdiDvW'},
#      'href': 'https://api.spotify.com/v1/albums/6lMlX68jJrx67hiCqdiDvW',
#      'id': '6lMlX68jJrx67hiCqdiDvW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a69b8b111a5fb8cb1c97e8eb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a69b8b111a5fb8cb1c97e8eb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a69b8b111a5fb8cb1c97e8eb',
#        'width': 64}],
#      'name': 'bad guy (with Justin Bieber)',
#      'release_date': '2019-07-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6lMlX68jJrx67hiCqdiDvW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'disc_number': 1,
#     'duration_ms': 194839,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71912813'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3yNZ5r3LKfdmjoS3gkhUCT'},
#     'href': 'https://api.spotify.com/v1/tracks/3yNZ5r3LKfdmjoS3gkhUCT',
#     'id': '3yNZ5r3LKfdmjoS3gkhUCT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy (with Justin Bieber)',
#     'popularity': 70,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3yNZ5r3LKfdmjoS3gkhUCT'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5B1tzDsgFcD5WGFis8I47I'},
#      'href': 'https://api.spotify.com/v1/albums/5B1tzDsgFcD5WGFis8I47I',
#      'id': '5B1tzDsgFcD5WGFis8I47I',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27363e5566ee923972083f8078b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0263e5566ee923972083f8078b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485163e5566ee923972083f8078b',
#        'width': 64}],
#      'name': 'Pop Queens',
#      'release_date': '2022-02-14',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:5B1tzDsgFcD5WGFis8I47I'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 194087,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1fLP2a8rubLRbXkojN98PS'},
#     'href': 'https://api.spotify.com/v1/tracks/1fLP2a8rubLRbXkojN98PS',
#     'id': '1fLP2a8rubLRbXkojN98PS',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 2,
#     'preview_url': None,
#     'track_number': 14,
#     'type': 'track',
#     'uri': 'spotify:track:1fLP2a8rubLRbXkojN98PS'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#        'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#        'id': '6MERXsiRbur2oJZFgYRDKz',
#        'name': 'Vitamin String Quartet',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wWBoQpcybsDVpouFubTqZ'},
#        'href': 'https://api.spotify.com/v1/artists/2wWBoQpcybsDVpouFubTqZ',
#        'id': '2wWBoQpcybsDVpouFubTqZ',
#        'name': 'Kris Bowers',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wWBoQpcybsDVpouFubTqZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5dhbc8LcvYmiI2CQhByaBR'},
#        'href': 'https://api.spotify.com/v1/artists/5dhbc8LcvYmiI2CQhByaBR',
#        'id': '5dhbc8LcvYmiI2CQhByaBR',
#        'name': 'Duomo',
#        'type': 'artist',
#        'uri': 'spotify:artist:5dhbc8LcvYmiI2CQhByaBR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5zdSoEL5yn9hXs7bJQdnqe'},
#      'href': 'https://api.spotify.com/v1/albums/5zdSoEL5yn9hXs7bJQdnqe',
#      'id': '5zdSoEL5yn9hXs7bJQdnqe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a40f30c4800e43a7df2aa1a7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a40f30c4800e43a7df2aa1a7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a40f30c4800e43a7df2aa1a7',
#        'width': 64}],
#      'name': 'Bridgerton (Covers from the Netflix Original Series)',
#      'release_date': '2020-12-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5zdSoEL5yn9hXs7bJQdnqe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#       'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#       'id': '6MERXsiRbur2oJZFgYRDKz',
#       'name': 'Vitamin String Quartet',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'}],
#     'disc_number': 1,
#     'duration_ms': 193226,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1990865'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1qOsHMitiWT4Zhx9ICzmjW'},
#     'href': 'https://api.spotify.com/v1/tracks/1qOsHMitiWT4Zhx9ICzmjW',
#     'id': '1qOsHMitiWT4Zhx9ICzmjW',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 57,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ade44136b9097dd0cfeaf78fef7907a45e494499?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1qOsHMitiWT4Zhx9ICzmjW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ND0mGcL9SKSjWIjPd0xIb'},
#        'href': 'https://api.spotify.com/v1/artists/5ND0mGcL9SKSjWIjPd0xIb',
#        'id': '5ND0mGcL9SKSjWIjPd0xIb',
#        'name': 'Bowling For Soup',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ND0mGcL9SKSjWIjPd0xIb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2safYwJ4j0WKLcQUwEBQEi'},
#      'href': 'https://api.spotify.com/v1/albums/2safYwJ4j0WKLcQUwEBQEi',
#      'id': '2safYwJ4j0WKLcQUwEBQEi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27397ed7b212715424daac8c600',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0297ed7b212715424daac8c600',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485197ed7b212715424daac8c600',
#        'width': 64}],
#      'name': 'Drunk Enough To Dance',
#      'release_date': '2002',
#      'release_date_precision': 'year',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:2safYwJ4j0WKLcQUwEBQEi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ND0mGcL9SKSjWIjPd0xIb'},
#       'href': 'https://api.spotify.com/v1/artists/5ND0mGcL9SKSjWIjPd0xIb',
#       'id': '5ND0mGcL9SKSjWIjPd0xIb',
#       'name': 'Bowling For Soup',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ND0mGcL9SKSjWIjPd0xIb'}],
#     'disc_number': 1,
#     'duration_ms': 197800,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10200080'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0KqyBk4aVT88TEqBIC8mAP'},
#     'href': 'https://api.spotify.com/v1/tracks/0KqyBk4aVT88TEqBIC8mAP',
#     'id': '0KqyBk4aVT88TEqBIC8mAP',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Girl All the Bad Guys Want',
#     'popularity': 66,
#     'preview_url': 'https://p.scdn.co/mp3-preview/602c25b41bc15d7631b0176c6efb9687e436ee8f?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0KqyBk4aVT88TEqBIC8mAP'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jDwZUFYUH1dC4xWzOd8QU'},
#        'href': 'https://api.spotify.com/v1/artists/6jDwZUFYUH1dC4xWzOd8QU',
#        'id': '6jDwZUFYUH1dC4xWzOd8QU',
#        'name': 'Caleb Hyles',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jDwZUFYUH1dC4xWzOd8QU'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3NDmzlfi4cf5fFPxsjMLuz'},
#      'href': 'https://api.spotify.com/v1/albums/3NDmzlfi4cf5fFPxsjMLuz',
#      'id': '3NDmzlfi4cf5fFPxsjMLuz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e10a38fc64912978e1a2aca3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e10a38fc64912978e1a2aca3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e10a38fc64912978e1a2aca3',
#        'width': 64}],
#      'name': "I'm the Bad Guy",
#      'release_date': '2017-02-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3NDmzlfi4cf5fFPxsjMLuz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jDwZUFYUH1dC4xWzOd8QU'},
#       'href': 'https://api.spotify.com/v1/artists/6jDwZUFYUH1dC4xWzOd8QU',
#       'id': '6jDwZUFYUH1dC4xWzOd8QU',
#       'name': 'Caleb Hyles',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jDwZUFYUH1dC4xWzOd8QU'}],
#     'disc_number': 1,
#     'duration_ms': 144169,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ4JJ1790058'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4FoRp17jtblWkNCfPe9QEU'},
#     'href': 'https://api.spotify.com/v1/tracks/4FoRp17jtblWkNCfPe9QEU',
#     'id': '4FoRp17jtblWkNCfPe9QEU',
#     'is_local': False,
#     'is_playable': True,
#     'name': "I'm the Bad Guy",
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d66ee9af3596cb68bba89342b893aef9e57f3e7b?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4FoRp17jtblWkNCfPe9QEU'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CmaKO2zEGJ1NWpS1yfVGz'},
#        'href': 'https://api.spotify.com/v1/artists/2CmaKO2zEGJ1NWpS1yfVGz',
#        'id': '2CmaKO2zEGJ1NWpS1yfVGz',
#        'name': 'Falling In Reverse',
#        'type': 'artist',
#        'uri': 'spotify:artist:2CmaKO2zEGJ1NWpS1yfVGz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KwwS07TEbKS8r1rU4UUe4'},
#      'href': 'https://api.spotify.com/v1/albums/1KwwS07TEbKS8r1rU4UUe4',
#      'id': '1KwwS07TEbKS8r1rU4UUe4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a4546ed22694f4297f6bdb9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a4546ed22694f4297f6bdb9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a4546ed22694f4297f6bdb9',
#        'width': 64}],
#      'name': 'The Drug In Me Is You',
#      'release_date': '2011-07-26',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1KwwS07TEbKS8r1rU4UUe4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CmaKO2zEGJ1NWpS1yfVGz'},
#       'href': 'https://api.spotify.com/v1/artists/2CmaKO2zEGJ1NWpS1yfVGz',
#       'id': '2CmaKO2zEGJ1NWpS1yfVGz',
#       'name': 'Falling In Reverse',
#       'type': 'artist',
#       'uri': 'spotify:artist:2CmaKO2zEGJ1NWpS1yfVGz'}],
#     'disc_number': 1,
#     'duration_ms': 195373,
#     'explicit': True,
#     'external_ids': {'isrc': 'USEP41118005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/78ML3F5Lz3KiNkpnFAaR3q'},
#     'href': 'https://api.spotify.com/v1/tracks/78ML3F5Lz3KiNkpnFAaR3q',
#     'id': '78ML3F5Lz3KiNkpnFAaR3q',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Good Girls Bad Guys',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4483445ed69c135c2792f383d9237cb5720ad14d?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:78ML3F5Lz3KiNkpnFAaR3q'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#        'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#        'id': '3bn93QEHOITZ4ARuiZdfRA',
#        'name': 'Morrisson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VNMclLseLzRnVhvkrqdpn'},
#        'href': 'https://api.spotify.com/v1/artists/5VNMclLseLzRnVhvkrqdpn',
#        'id': '5VNMclLseLzRnVhvkrqdpn',
#        'name': 'Loski',
#        'type': 'artist',
#        'uri': 'spotify:artist:5VNMclLseLzRnVhvkrqdpn'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1lHttlzArtuCKOvxe12DN3'},
#      'href': 'https://api.spotify.com/v1/albums/1lHttlzArtuCKOvxe12DN3',
#      'id': '1lHttlzArtuCKOvxe12DN3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731a4dfd9835c62bf673851d87',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021a4dfd9835c62bf673851d87',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511a4dfd9835c62bf673851d87',
#        'width': 64}],
#      'name': 'Bad Guy (feat. Loski)',
#      'release_date': '2020-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1lHttlzArtuCKOvxe12DN3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#       'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#       'id': '3bn93QEHOITZ4ARuiZdfRA',
#       'name': 'Morrisson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VNMclLseLzRnVhvkrqdpn'},
#       'href': 'https://api.spotify.com/v1/artists/5VNMclLseLzRnVhvkrqdpn',
#       'id': '5VNMclLseLzRnVhvkrqdpn',
#       'name': 'Loski',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VNMclLseLzRnVhvkrqdpn'}],
#     'disc_number': 1,
#     'duration_ms': 221560,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBARL2001262'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1VQKKey9XgeYOm6rd1Aje8'},
#     'href': 'https://api.spotify.com/v1/tracks/1VQKKey9XgeYOm6rd1Aje8',
#     'id': '1VQKKey9XgeYOm6rd1Aje8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (feat. Loski)',
#     'popularity': 47,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ffaee530669430311b858529dcec230027d19aa8?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1VQKKey9XgeYOm6rd1Aje8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#        'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#        'id': '3f626JSVauIhTQgatsFcs4',
#        'name': 'Paul Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Je0MVXBcSsJ3dhXXjYJpv'},
#      'href': 'https://api.spotify.com/v1/albums/4Je0MVXBcSsJ3dhXXjYJpv',
#      'id': '4Je0MVXBcSsJ3dhXXjYJpv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bec3afb4a8379d8adf24b1a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bec3afb4a8379d8adf24b1a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bec3afb4a8379d8adf24b1a2',
#        'width': 64}],
#      'name': 'Bugsy Malone (From "Bugsy Malone" Original Motion Picture Soundtrack)',
#      'release_date': '1976-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4Je0MVXBcSsJ3dhXXjYJpv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#       'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#       'id': '3f626JSVauIhTQgatsFcs4',
#       'name': 'Paul Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#     'disc_number': 1,
#     'duration_ms': 136133,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAKW7600475'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3gZoHbFt5W3HltDGcnbDrD'},
#     'href': 'https://api.spotify.com/v1/tracks/3gZoHbFt5W3HltDGcnbDrD',
#     'id': '3gZoHbFt5W3HltDGcnbDrD',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guys - From "Bugsy Malone" Original Motion Picture Soundtrack',
#     'popularity': 40,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3gZoHbFt5W3HltDGcnbDrD'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kART38d9tWb1yOcSO40YH'},
#        'href': 'https://api.spotify.com/v1/artists/6kART38d9tWb1yOcSO40YH',
#        'id': '6kART38d9tWb1yOcSO40YH',
#        'name': 'Eklipse',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kART38d9tWb1yOcSO40YH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7jgCENuww6WXc03Gpm3bKe'},
#      'href': 'https://api.spotify.com/v1/albums/7jgCENuww6WXc03Gpm3bKe',
#      'id': '7jgCENuww6WXc03Gpm3bKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a4bfa1801605c62c6d102346',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a4bfa1801605c62c6d102346',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a4bfa1801605c62c6d102346',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2020-05-29',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7jgCENuww6WXc03Gpm3bKe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kART38d9tWb1yOcSO40YH'},
#       'href': 'https://api.spotify.com/v1/artists/6kART38d9tWb1yOcSO40YH',
#       'id': '6kART38d9tWb1yOcSO40YH',
#       'name': 'Eklipse',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kART38d9tWb1yOcSO40YH'}],
#     'disc_number': 1,
#     'duration_ms': 191974,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEPI82010434'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2FH0jT9o0mz71s7AtMkAa4'},
#     'href': 'https://api.spotify.com/v1/tracks/2FH0jT9o0mz71s7AtMkAa4',
#     'id': '2FH0jT9o0mz71s7AtMkAa4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7d1a0c4902ce05ab4b902059e4e1679a79abd6b2?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2FH0jT9o0mz71s7AtMkAa4'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/10nO3EJJDMm6j6d2uK3Jah'},
#      'href': 'https://api.spotify.com/v1/albums/10nO3EJJDMm6j6d2uK3Jah',
#      'id': '10nO3EJJDMm6j6d2uK3Jah',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d12909c6ebc83cb4c6bef6f4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d12909c6ebc83cb4c6bef6f4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d12909c6ebc83cb4c6bef6f4',
#        'width': 64}],
#      'name': 'The Slim Shady LP (Expanded Edition)',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:10nO3EJJDMm6j6d2uK3Jah'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6DPYiyq5kWVQS4RGwxzPC7'},
#       'href': 'https://api.spotify.com/v1/artists/6DPYiyq5kWVQS4RGwxzPC7',
#       'id': '6DPYiyq5kWVQS4RGwxzPC7',
#       'name': 'Dr. Dre',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DPYiyq5kWVQS4RGwxzPC7'}],
#     'disc_number': 1,
#     'duration_ms': 279133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR19902296'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4KVVy0GeXO03ni8Cv4SWk8'},
#     'href': 'https://api.spotify.com/v1/tracks/4KVVy0GeXO03ni8Cv4SWk8',
#     'id': '4KVVy0GeXO03ni8Cv4SWk8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guys Always Die - From "Wild Wild West" Soundtrack',
#     'popularity': 50,
#     'preview_url': None,
#     'track_number': 24,
#     'type': 'track',
#     'uri': 'spotify:track:4KVVy0GeXO03ni8Cv4SWk8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#        'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#        'id': '6eUKZXaKkcviH0Ku9w2n3V',
#        'name': 'Ed Sheeran',
#        'type': 'artist',
#        'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/32iAEBstCjauDhyKpGjTuq'},
#      'href': 'https://api.spotify.com/v1/albums/32iAEBstCjauDhyKpGjTuq',
#      'id': '32iAEBstCjauDhyKpGjTuq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ef24c3fdbf856340d55cfeb2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ef24c3fdbf856340d55cfeb2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ef24c3fdbf856340d55cfeb2',
#        'width': 64}],
#      'name': '=',
#      'release_date': '2021-10-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:32iAEBstCjauDhyKpGjTuq'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6eUKZXaKkcviH0Ku9w2n3V'},
#       'href': 'https://api.spotify.com/v1/artists/6eUKZXaKkcviH0Ku9w2n3V',
#       'id': '6eUKZXaKkcviH0Ku9w2n3V',
#       'name': 'Ed Sheeran',
#       'type': 'artist',
#       'uri': 'spotify:artist:6eUKZXaKkcviH0Ku9w2n3V'}],
#     'disc_number': 1,
#     'duration_ms': 230746,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAHS2100318'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3rmo8F54jFF8OgYsqTxm5d'},
#     'href': 'https://api.spotify.com/v1/tracks/3rmo8F54jFF8OgYsqTxm5d',
#     'id': '3rmo8F54jFF8OgYsqTxm5d',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Habits',
#     'popularity': 95,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e0440ae1a5a38687fb54170742e9b83ebd33ddf3?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3rmo8F54jFF8OgYsqTxm5d'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06bDwgCHeMAwhgI8il4Y5k'},
#        'href': 'https://api.spotify.com/v1/artists/06bDwgCHeMAwhgI8il4Y5k',
#        'id': '06bDwgCHeMAwhgI8il4Y5k',
#        'name': 'Set It Off',
#        'type': 'artist',
#        'uri': 'spotify:artist:06bDwgCHeMAwhgI8il4Y5k'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4mPWTksMsByAvomErPtJwK'},
#      'href': 'https://api.spotify.com/v1/albums/4mPWTksMsByAvomErPtJwK',
#      'id': '4mPWTksMsByAvomErPtJwK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eef2f969585ecd89a33564c6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eef2f969585ecd89a33564c6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eef2f969585ecd89a33564c6',
#        'width': 64}],
#      'name': 'Duality',
#      'release_date': '2014-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4mPWTksMsByAvomErPtJwK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06bDwgCHeMAwhgI8il4Y5k'},
#       'href': 'https://api.spotify.com/v1/artists/06bDwgCHeMAwhgI8il4Y5k',
#       'id': '06bDwgCHeMAwhgI8il4Y5k',
#       'name': 'Set It Off',
#       'type': 'artist',
#       'uri': 'spotify:artist:06bDwgCHeMAwhgI8il4Y5k'}],
#     'disc_number': 1,
#     'duration_ms': 189226,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITH711400136'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/760frpppJAxqsVBuiOt1yL'},
#     'href': 'https://api.spotify.com/v1/tracks/760frpppJAxqsVBuiOt1yL',
#     'id': '760frpppJAxqsVBuiOt1yL',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/90731228ba858593a01cdd16c0a966f05dc2f638?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:760frpppJAxqsVBuiOt1yL'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hkBUDhKEiz64k5kTrd1QQ'},
#        'href': 'https://api.spotify.com/v1/artists/3hkBUDhKEiz64k5kTrd1QQ',
#        'id': '3hkBUDhKEiz64k5kTrd1QQ',
#        'name': 'Crypto',
#        'type': 'artist',
#        'uri': 'spotify:artist:3hkBUDhKEiz64k5kTrd1QQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Au2Jv6CGEyc9FLVT7moz9'},
#      'href': 'https://api.spotify.com/v1/albums/3Au2Jv6CGEyc9FLVT7moz9',
#      'id': '3Au2Jv6CGEyc9FLVT7moz9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732d78170c142e43270a2b34a0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022d78170c142e43270a2b34a0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512d78170c142e43270a2b34a0',
#        'width': 64}],
#      'name': 'bad guy',
#      'release_date': '2022-01-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3Au2Jv6CGEyc9FLVT7moz9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3hkBUDhKEiz64k5kTrd1QQ'},
#       'href': 'https://api.spotify.com/v1/artists/3hkBUDhKEiz64k5kTrd1QQ',
#       'id': '3hkBUDhKEiz64k5kTrd1QQ',
#       'name': 'Crypto',
#       'type': 'artist',
#       'uri': 'spotify:artist:3hkBUDhKEiz64k5kTrd1QQ'}],
#     'disc_number': 1,
#     'duration_ms': 138082,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEWO71700303'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4727RsuKMuY09HnC1ZD6yt'},
#     'href': 'https://api.spotify.com/v1/tracks/4727RsuKMuY09HnC1ZD6yt',
#     'id': '4727RsuKMuY09HnC1ZD6yt',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 50,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c67e37ff3305228778c7f95b8ebfed8e80b3d03b?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4727RsuKMuY09HnC1ZD6yt'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#        'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#        'id': '3bn93QEHOITZ4ARuiZdfRA',
#        'name': 'Morrisson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6TJhrY1zpxLFbrKDAM5Nci'},
#      'href': 'https://api.spotify.com/v1/albums/6TJhrY1zpxLFbrKDAM5Nci',
#      'id': '6TJhrY1zpxLFbrKDAM5Nci',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d3824f87f0c4401bbba74087',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d3824f87f0c4401bbba74087',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d3824f87f0c4401bbba74087',
#        'width': 64}],
#      'name': 'Guilty',
#      'release_date': '2021-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:6TJhrY1zpxLFbrKDAM5Nci'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#       'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#       'id': '3bn93QEHOITZ4ARuiZdfRA',
#       'name': 'Morrisson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VNMclLseLzRnVhvkrqdpn'},
#       'href': 'https://api.spotify.com/v1/artists/5VNMclLseLzRnVhvkrqdpn',
#       'id': '5VNMclLseLzRnVhvkrqdpn',
#       'name': 'Loski',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VNMclLseLzRnVhvkrqdpn'}],
#     'disc_number': 1,
#     'duration_ms': 221560,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBARL2001262'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7vLzU22xRA0pz9A8Ch1NNl'},
#     'href': 'https://api.spotify.com/v1/tracks/7vLzU22xRA0pz9A8Ch1NNl',
#     'id': '7vLzU22xRA0pz9A8Ch1NNl',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (feat. Loski)',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/67f8bcf80e56e51251355279f3a28c84e09d7bad?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7vLzU22xRA0pz9A8Ch1NNl'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gvJCmaQhMlqFpXCaz9o3l'},
#        'href': 'https://api.spotify.com/v1/artists/7gvJCmaQhMlqFpXCaz9o3l',
#        'id': '7gvJCmaQhMlqFpXCaz9o3l',
#        'name': '7AM',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gvJCmaQhMlqFpXCaz9o3l'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Btky5ia7ihAQE8UEXPmbQ'},
#        'href': 'https://api.spotify.com/v1/artists/0Btky5ia7ihAQE8UEXPmbQ',
#        'id': '0Btky5ia7ihAQE8UEXPmbQ',
#        'name': 'DJ Boat',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Btky5ia7ihAQE8UEXPmbQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2UMoEumdcdZdCjZChHIjBh'},
#      'href': 'https://api.spotify.com/v1/albums/2UMoEumdcdZdCjZChHIjBh',
#      'id': '2UMoEumdcdZdCjZChHIjBh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738445b0e6be4f5bcf897e48f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028445b0e6be4f5bcf897e48f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518445b0e6be4f5bcf897e48f5',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2021-09-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2UMoEumdcdZdCjZChHIjBh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gvJCmaQhMlqFpXCaz9o3l'},
#       'href': 'https://api.spotify.com/v1/artists/7gvJCmaQhMlqFpXCaz9o3l',
#       'id': '7gvJCmaQhMlqFpXCaz9o3l',
#       'name': '7AM',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gvJCmaQhMlqFpXCaz9o3l'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Btky5ia7ihAQE8UEXPmbQ'},
#       'href': 'https://api.spotify.com/v1/artists/0Btky5ia7ihAQE8UEXPmbQ',
#       'id': '0Btky5ia7ihAQE8UEXPmbQ',
#       'name': 'DJ Boat',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Btky5ia7ihAQE8UEXPmbQ'}],
#     'disc_number': 1,
#     'duration_ms': 150810,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZK6H2157492'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0iXlgib8Sp7tU0tRdoUJYg'},
#     'href': 'https://api.spotify.com/v1/tracks/0iXlgib8Sp7tU0tRdoUJYg',
#     'id': '0iXlgib8Sp7tU0tRdoUJYg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a0f17b425c0721beb95b73d765fe1003e811bcd4?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0iXlgib8Sp7tU0tRdoUJYg'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3vOgbDjgsZBAPwV2M3bNOj'},
#      'href': 'https://api.spotify.com/v1/albums/3vOgbDjgsZBAPwV2M3bNOj',
#      'id': '3vOgbDjgsZBAPwV2M3bNOj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27357195dfe8926f713b21d6cac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0257195dfe8926f713b21d6cac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485157195dfe8926f713b21d6cac',
#        'width': 64}],
#      'name': 'The Marshall Mathers LP2',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3vOgbDjgsZBAPwV2M3bNOj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 434077,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71314073'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5SpWTzTFzy2UiZWaEWCHWn'},
#     'href': 'https://api.spotify.com/v1/tracks/5SpWTzTFzy2UiZWaEWCHWn',
#     'id': '5SpWTzTFzy2UiZWaEWCHWn',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 46,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5SpWTzTFzy2UiZWaEWCHWn'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6G1yTgvoYsuVb2Ja8cVVJ2'},
#        'href': 'https://api.spotify.com/v1/artists/6G1yTgvoYsuVb2Ja8cVVJ2',
#        'id': '6G1yTgvoYsuVb2Ja8cVVJ2',
#        'name': 'anders',
#        'type': 'artist',
#        'uri': 'spotify:artist:6G1yTgvoYsuVb2Ja8cVVJ2'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6JA8PoWci8XU2K2CKLpkaP'},
#      'href': 'https://api.spotify.com/v1/albums/6JA8PoWci8XU2K2CKLpkaP',
# ...
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0wshRM4FuMv9D0TiCCYAJa'},
#       'href': 'https://api.spotify.com/v1/artists/0wshRM4FuMv9D0TiCCYAJa',
#       'id': '0wshRM4FuMv9D0TiCCYAJa',
#       'name': 'new.wav',
#       'type': 'artist',
#       'uri': 'spotify:artist:0wshRM4FuMv9D0TiCCYAJa'}],
#     'disc_number': 1,
#     'duration_ms': 202892,
#     'explicit': True,
#     'external_ids': {'isrc': 'QM24S1922922'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5IGPVZnHthItuYm9hPAclA'},
#     'href': 'https://api.spotify.com/v1/tracks/5IGPVZnHthItuYm9hPAclA',
#     'id': '5IGPVZnHthItuYm9hPAclA',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3f18c9ecea68d31e92d77b70f91aaef2ab0feee1?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5IGPVZnHthItuYm9hPAclA'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5py7utGDgkOSj26N1boPUc'},
#        'href': 'https://api.spotify.com/v1/artists/5py7utGDgkOSj26N1boPUc',
#        'id': '5py7utGDgkOSj26N1boPUc',
#        'name': 'Ellery Hughes',
#        'type': 'artist',
#        'uri': 'spotify:artist:5py7utGDgkOSj26N1boPUc'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4DLDpkEbrYKgYNpIEudHsV'},
#      'href': 'https://api.spotify.com/v1/albums/4DLDpkEbrYKgYNpIEudHsV',
#      'id': '4DLDpkEbrYKgYNpIEudHsV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e99499a0fad51bc692ea4bea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e99499a0fad51bc692ea4bea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e99499a0fad51bc692ea4bea',
#        'width': 64}],
#      'name': 'A Collection of Instrumental Piano Covers',
#      'release_date': '2020-08-14',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:4DLDpkEbrYKgYNpIEudHsV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5py7utGDgkOSj26N1boPUc'},
#       'href': 'https://api.spotify.com/v1/artists/5py7utGDgkOSj26N1boPUc',
#       'id': '5py7utGDgkOSj26N1boPUc',
#       'name': 'Ellery Hughes',
#       'type': 'artist',
#       'uri': 'spotify:artist:5py7utGDgkOSj26N1boPUc'}],
#     'disc_number': 1,
#     'duration_ms': 160333,
#     'explicit': False,
#     'external_ids': {'isrc': 'UKG8V2000832'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4MClHPCWt88zdf14ztJnAz'},
#     'href': 'https://api.spotify.com/v1/tracks/4MClHPCWt88zdf14ztJnAz',
#     'id': '4MClHPCWt88zdf14ztJnAz',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/647ba98b09b6501a1c924628c160a56a13ea8ce4?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4MClHPCWt88zdf14ztJnAz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KWOCu1saEHAhPiLKlOLIy'},
#        'href': 'https://api.spotify.com/v1/artists/5KWOCu1saEHAhPiLKlOLIy',
#        'id': '5KWOCu1saEHAhPiLKlOLIy',
#        'name': 'Leo',
#        'type': 'artist',
#        'uri': 'spotify:artist:5KWOCu1saEHAhPiLKlOLIy'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7fvUH89It4owIx5Yjnd661'},
#      'href': 'https://api.spotify.com/v1/albums/7fvUH89It4owIx5Yjnd661',
#      'id': '7fvUH89It4owIx5Yjnd661',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f22dff079307df0b3c50999d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f22dff079307df0b3c50999d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f22dff079307df0b3c50999d',
#        'width': 64}],
#      'name': 'Leo Metal, Vol. 24',
#      'release_date': '2019-06-20',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7fvUH89It4owIx5Yjnd661'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5KWOCu1saEHAhPiLKlOLIy'},
#       'href': 'https://api.spotify.com/v1/artists/5KWOCu1saEHAhPiLKlOLIy',
#       'id': '5KWOCu1saEHAhPiLKlOLIy',
#       'name': 'Leo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KWOCu1saEHAhPiLKlOLIy'}],
#     'disc_number': 1,
#     'duration_ms': 232085,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZGWW1912040'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5asn6PSAQN0mbmRV7FquIy'},
#     'href': 'https://api.spotify.com/v1/tracks/5asn6PSAQN0mbmRV7FquIy',
#     'id': '5asn6PSAQN0mbmRV7FquIy',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (Metal Version)',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7d9666721bf530ec63f8589fb68cd538b43a622f?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5asn6PSAQN0mbmRV7FquIy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7t2C8WwLyKUKRe0LVh8zl9'},
#        'href': 'https://api.spotify.com/v1/artists/7t2C8WwLyKUKRe0LVh8zl9',
#        'id': '7t2C8WwLyKUKRe0LVh8zl9',
#        'name': 'blessthefall',
#        'type': 'artist',
#        'uri': 'spotify:artist:7t2C8WwLyKUKRe0LVh8zl9'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3ANtCCvIfTVZexgdh0LXdM'},
#      'href': 'https://api.spotify.com/v1/albums/3ANtCCvIfTVZexgdh0LXdM',
#      'id': '3ANtCCvIfTVZexgdh0LXdM',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732b99d1d1103ffba5e8baeeb5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022b99d1d1103ffba5e8baeeb5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512b99d1d1103ffba5e8baeeb5',
#        'width': 64}],
#      'name': 'His Last Walk',
#      'release_date': '2007',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3ANtCCvIfTVZexgdh0LXdM'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7t2C8WwLyKUKRe0LVh8zl9'},
#       'href': 'https://api.spotify.com/v1/artists/7t2C8WwLyKUKRe0LVh8zl9',
#       'id': '7t2C8WwLyKUKRe0LVh8zl9',
#       'name': 'blessthefall',
#       'type': 'artist',
#       'uri': 'spotify:artist:7t2C8WwLyKUKRe0LVh8zl9'}],
#     'disc_number': 1,
#     'duration_ms': 235640,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRC20600119'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/75rctYH1J87zkJ51c4cxaq'},
#     'href': 'https://api.spotify.com/v1/tracks/75rctYH1J87zkJ51c4cxaq',
#     'id': '75rctYH1J87zkJ51c4cxaq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Guys Like You Make Us Look Bad',
#     'popularity': 52,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4c82dece5110ff1e73795db117475d0a55638095?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:75rctYH1J87zkJ51c4cxaq'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ZGgc6iTKy5XJVPwlxxfei'},
#        'href': 'https://api.spotify.com/v1/artists/3ZGgc6iTKy5XJVPwlxxfei',
#        'id': '3ZGgc6iTKy5XJVPwlxxfei',
#        'name': 'Alex Holtti',
#        'type': 'artist',
#        'uri': 'spotify:artist:3ZGgc6iTKy5XJVPwlxxfei'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0vemzfhT26oLMg0BzcnZss'},
#      'href': 'https://api.spotify.com/v1/albums/0vemzfhT26oLMg0BzcnZss',
#      'id': '0vemzfhT26oLMg0BzcnZss',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27375f0464af6e7e4047bea8844',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0275f0464af6e7e4047bea8844',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485175f0464af6e7e4047bea8844',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2019-02-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0vemzfhT26oLMg0BzcnZss'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ZGgc6iTKy5XJVPwlxxfei'},
#       'href': 'https://api.spotify.com/v1/artists/3ZGgc6iTKy5XJVPwlxxfei',
#       'id': '3ZGgc6iTKy5XJVPwlxxfei',
#       'name': 'Alex Holtti',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ZGgc6iTKy5XJVPwlxxfei'}],
#     'disc_number': 1,
#     'duration_ms': 214958,
#     'explicit': False,
#     'external_ids': {'isrc': 'DKQ271900101'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3AeemxsZeLT9GXZJZlPc1U'},
#     'href': 'https://api.spotify.com/v1/tracks/3AeemxsZeLT9GXZJZlPc1U',
#     'id': '3AeemxsZeLT9GXZJZlPc1U',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 30,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3AeemxsZeLT9GXZJZlPc1U'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/18KIg6ST1nUjVUvAlEB6ak'},
#        'href': 'https://api.spotify.com/v1/artists/18KIg6ST1nUjVUvAlEB6ak',
#        'id': '18KIg6ST1nUjVUvAlEB6ak',
#        'name': 'Vo Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:18KIg6ST1nUjVUvAlEB6ak'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3yb3vL7b03IIb2hkY3okOU'},
#      'href': 'https://api.spotify.com/v1/albums/3yb3vL7b03IIb2hkY3okOU',
#      'id': '3yb3vL7b03IIb2hkY3okOU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ecd8ac00cba6c89cec8c5738',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ecd8ac00cba6c89cec8c5738',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ecd8ac00cba6c89cec8c5738',
#        'width': 64}],
#      'name': 'BAD GUY',
#      'release_date': '2021-03-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3yb3vL7b03IIb2hkY3okOU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/18KIg6ST1nUjVUvAlEB6ak'},
#       'href': 'https://api.spotify.com/v1/artists/18KIg6ST1nUjVUvAlEB6ak',
#       'id': '18KIg6ST1nUjVUvAlEB6ak',
#       'name': 'Vo Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:18KIg6ST1nUjVUvAlEB6ak'}],
#     'disc_number': 1,
#     'duration_ms': 181395,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM24S2101472'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5D6IIoEAfIPgYYhcR8INFV'},
#     'href': 'https://api.spotify.com/v1/tracks/5D6IIoEAfIPgYYhcR8INFV',
#     'id': '5D6IIoEAfIPgYYhcR8INFV',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'BAD GUY',
#     'popularity': 41,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6ae8dc2563c86466165d8a8543ed75e7095f3908?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5D6IIoEAfIPgYYhcR8INFV'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZZafCTzyk1yjqEES63cMm'},
#        'href': 'https://api.spotify.com/v1/artists/6ZZafCTzyk1yjqEES63cMm',
#        'id': '6ZZafCTzyk1yjqEES63cMm',
#        'name': '1THE9',
#        'type': 'artist',
#        'uri': 'spotify:artist:6ZZafCTzyk1yjqEES63cMm'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0iabKdP4AZGklJ9oH6nbob'},
#      'href': 'https://api.spotify.com/v1/albums/0iabKdP4AZGklJ9oH6nbob',
#      'id': '0iabKdP4AZGklJ9oH6nbob',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b77d998d44bb5b92c52705ea',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b77d998d44bb5b92c52705ea',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b77d998d44bb5b92c52705ea',
#        'width': 64}],
#      'name': 'Turn Over',
#      'release_date': '2020-07-16',
#      'release_date_precision': 'day',
#      'total_tracks': 5,
#      'type': 'album',
#      'uri': 'spotify:album:0iabKdP4AZGklJ9oH6nbob'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6ZZafCTzyk1yjqEES63cMm'},
#       'href': 'https://api.spotify.com/v1/artists/6ZZafCTzyk1yjqEES63cMm',
#       'id': '6ZZafCTzyk1yjqEES63cMm',
#       'name': '1THE9',
#       'type': 'artist',
#       'uri': 'spotify:artist:6ZZafCTzyk1yjqEES63cMm'}],
#     'disc_number': 1,
#     'duration_ms': 214946,
#     'explicit': False,
#     'external_ids': {'isrc': 'KRA382002977'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5DumPcJlq92SLNjAWiZW93'},
#     'href': 'https://api.spotify.com/v1/tracks/5DumPcJlq92SLNjAWiZW93',
#     'id': '5DumPcJlq92SLNjAWiZW93',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bb3780ad015484e6948edece39f8d651e4ae708f?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5DumPcJlq92SLNjAWiZW93'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3mGCLimuzOdod4Lnegny4d'},
#        'href': 'https://api.spotify.com/v1/artists/3mGCLimuzOdod4Lnegny4d',
#        'id': '3mGCLimuzOdod4Lnegny4d',
#        'name': 'Twinkle Twinkle Little Rock Star',
#        'type': 'artist',
#        'uri': 'spotify:artist:3mGCLimuzOdod4Lnegny4d'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0yDP0J4ZciiNVILWLR0bQc'},
#      'href': 'https://api.spotify.com/v1/albums/0yDP0J4ZciiNVILWLR0bQc',
#      'id': '0yDP0J4ZciiNVILWLR0bQc',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733cff16d899cd1bacc85c5892',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023cff16d899cd1bacc85c5892',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513cff16d899cd1bacc85c5892',
#        'width': 64}],
#      'name': 'Lullaby Versions of Billie Eilish',
#      'release_date': '2020-06-05',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0yDP0J4ZciiNVILWLR0bQc'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3mGCLimuzOdod4Lnegny4d'},
#       'href': 'https://api.spotify.com/v1/artists/3mGCLimuzOdod4Lnegny4d',
#       'id': '3mGCLimuzOdod4Lnegny4d',
#       'name': 'Twinkle Twinkle Little Rock Star',
#       'type': 'artist',
#       'uri': 'spotify:artist:3mGCLimuzOdod4Lnegny4d'}],
#     'disc_number': 1,
#     'duration_ms': 266571,
#     'explicit': False,
#     'external_ids': {'isrc': 'USA2P2020276'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1IWuiJ7X8zaPmK9NiL0lH6'},
#     'href': 'https://api.spotify.com/v1/tracks/1IWuiJ7X8zaPmK9NiL0lH6',
#     'id': '1IWuiJ7X8zaPmK9NiL0lH6',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6476be198fcbeb69c42aea2a5aac59b6973fb833?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1IWuiJ7X8zaPmK9NiL0lH6'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Bad+Guy&type=track&market=GB&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 9995}}

# %%
song["tracks"]["items"][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:2Fxmhks0bxGSBdJ92vM42m'
# 'spotify:track:2Fxmhks0bxGSBdJ92vM42m'

# %% [markdown]
# ### Json

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=AA&type=track&market=GB&offset=0&limit=1
# The song's info is contained in:  [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'}, 'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N', 'id': '4aXXDj9aZnlshx7mzj3W1N', 'name': 'Lin-Manuel Miranda', 'type': 'artist', 'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1kCHru7uhxBUdzkm4gzRQc'}, 'href': 'https://api.spotify.com/v1/albums/1kCHru7uhxBUdzkm4gzRQc', 'id': '1kCHru7uhxBUdzkm4gzRQc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273d72fb5571087bca0a2fed008', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02d72fb5571087bca0a2fed008', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851d72fb5571087bca0a2fed008', 'width': 64}], 'name': 'Hamilton (Original Broadway Cast Recording)', 'release_date': '2015-09-25', 'release_date_precision': 'day', 'total_tracks': 46, 'type': 'album', 'uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'}, 'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N', 'id': '4aXXDj9aZnlshx7mzj3W1N', 'name': 'Lin-Manuel Miranda', 'type': 'artist', 'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3cR4rhS2hBWqI7rJEBacvN'}, 'href': 'https://api.spotify.com/v1/artists/3cR4rhS2hBWqI7rJEBacvN', 'id': '3cR4rhS2hBWqI7rJEBacvN', 'name': 'Leslie Odom Jr.', 'type': 'artist', 'uri': 'spotify:artist:3cR4rhS2hBWqI7rJEBacvN'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/660YptcR0hNHJ8iEr1qcse'}, 'href': 'https://api.spotify.com/v1/artists/660YptcR0hNHJ8iEr1qcse', 'id': '660YptcR0hNHJ8iEr1qcse', 'name': 'Anthony Ramos', 'type': 'artist', 'uri': 'spotify:artist:660YptcR0hNHJ8iEr1qcse'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3twuAojvYNrlWZpMkxLm3P'}, 'href': 'https://api.spotify.com/v1/artists/3twuAojvYNrlWZpMkxLm3P', 'id': '3twuAojvYNrlWZpMkxLm3P', 'name': 'Daveed Diggs', 'type': 'artist', 'uri': 'spotify:artist:3twuAojvYNrlWZpMkxLm3P'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6G3sPhnj4JBCsBVBGvZnkk'}, 'href': 'https://api.spotify.com/v1/artists/6G3sPhnj4JBCsBVBGvZnkk', 'id': '6G3sPhnj4JBCsBVBGvZnkk', 'name': 'Okieriete Onaodowan', 'type': 'artist', 'uri': 'spotify:artist:6G3sPhnj4JBCsBVBGvZnkk'}], 'disc_number': 1, 'duration_ms': 156630, 'explicit': False, 'external_ids': {'isrc': 'USAT21502597'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/6dr7ekfhlbquvsVY8D7gyk'}, 'href': 'https://api.spotify.com/v1/tracks/6dr7ekfhlbquvsVY8D7gyk', 'id': '6dr7ekfhlbquvsVY8D7gyk', 'is_local': False, 'is_playable': True, 'name': 'Aaron Burr, Sir', 'popularity': 71, 'preview_url': 'https://p.scdn.co/mp3-preview/a693bdbcde80bd0c4e9c3ee6078a30402533f202?cid=acf6602caa5749f79900cabb94c1c3e4', 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:6dr7ekfhlbquvsVY8D7gyk'}]
# The limit of the query we've made is:  1
# The next page if any:  https://api.spotify.com/v1/search?query=AA&type=track&market=GB&offset=1&limit=1
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  10031

# %% [markdown]
# #### Checking the Albums

# %%
print(results["tracks"]["items"][0]["album"]) # we have more info about the album
print("****************\n")
print(list(results["tracks"]["items"][0]["album"].keys())) # Will check artists, id, name, release date, total tracks 
print("****************\n")
print(results["tracks"]["items"][0]["album"]["artists"]) # List with artists and information
print("****************\n")
print("The album ID is: ",results["tracks"]["items"][0]["album"]["id"]) # Album ID 
print("****************\n")
print(results["tracks"]["items"][0]["album"]["name"]) # Album name (if its a single u'll get the name of the song)
# Out:
# {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'}, 'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N', 'id': '4aXXDj9aZnlshx7mzj3W1N', 'name': 'Lin-Manuel Miranda', 'type': 'artist', 'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1kCHru7uhxBUdzkm4gzRQc'}, 'href': 'https://api.spotify.com/v1/albums/1kCHru7uhxBUdzkm4gzRQc', 'id': '1kCHru7uhxBUdzkm4gzRQc', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273d72fb5571087bca0a2fed008', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02d72fb5571087bca0a2fed008', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851d72fb5571087bca0a2fed008', 'width': 64}], 'name': 'Hamilton (Original Broadway Cast Recording)', 'release_date': '2015-09-25', 'release_date_precision': 'day', 'total_tracks': 46, 'type': 'album', 'uri': 'spotify:album:1kCHru7uhxBUdzkm4gzRQc'}
# ****************
#
# ['album_type', 'artists', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
# ****************
#
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'}, 'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N', 'id': '4aXXDj9aZnlshx7mzj3W1N', 'name': 'Lin-Manuel Miranda', 'type': 'artist', 'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'}]
# ****************
#
# The album ID is:  1kCHru7uhxBUdzkm4gzRQc
# ****************
#
# Hamilton (Original Broadway Cast Recording)

# %% [markdown]
# #### Other Info

# %%
print(results["tracks"]["items"][0]["artists"]) # Track artists
print("****************\n")
print(results["tracks"]["items"][0]["id"]) # Track ID
print("****************\n")
print(results["tracks"]["items"][0]["name"]) # Track name
print("****************\n")
print(results["tracks"]["items"][0]["popularity"]) # Popularity index
print("****************\n")
print(results["tracks"]["items"][0]["uri"]) # Basically ID
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aXXDj9aZnlshx7mzj3W1N'}, 'href': 'https://api.spotify.com/v1/artists/4aXXDj9aZnlshx7mzj3W1N', 'id': '4aXXDj9aZnlshx7mzj3W1N', 'name': 'Lin-Manuel Miranda', 'type': 'artist', 'uri': 'spotify:artist:4aXXDj9aZnlshx7mzj3W1N'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3cR4rhS2hBWqI7rJEBacvN'}, 'href': 'https://api.spotify.com/v1/artists/3cR4rhS2hBWqI7rJEBacvN', 'id': '3cR4rhS2hBWqI7rJEBacvN', 'name': 'Leslie Odom Jr.', 'type': 'artist', 'uri': 'spotify:artist:3cR4rhS2hBWqI7rJEBacvN'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/660YptcR0hNHJ8iEr1qcse'}, 'href': 'https://api.spotify.com/v1/artists/660YptcR0hNHJ8iEr1qcse', 'id': '660YptcR0hNHJ8iEr1qcse', 'name': 'Anthony Ramos', 'type': 'artist', 'uri': 'spotify:artist:660YptcR0hNHJ8iEr1qcse'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/3twuAojvYNrlWZpMkxLm3P'}, 'href': 'https://api.spotify.com/v1/artists/3twuAojvYNrlWZpMkxLm3P', 'id': '3twuAojvYNrlWZpMkxLm3P', 'name': 'Daveed Diggs', 'type': 'artist', 'uri': 'spotify:artist:3twuAojvYNrlWZpMkxLm3P'}, {'external_urls': {'spotify': 'https://open.spotify.com/artist/6G3sPhnj4JBCsBVBGvZnkk'}, 'href': 'https://api.spotify.com/v1/artists/6G3sPhnj4JBCsBVBGvZnkk', 'id': '6G3sPhnj4JBCsBVBGvZnkk', 'name': 'Okieriete Onaodowan', 'type': 'artist', 'uri': 'spotify:artist:6G3sPhnj4JBCsBVBGvZnkk'}]
# ****************
#
# 6dr7ekfhlbquvsVY8D7gyk
# ****************
#
# Aaron Burr, Sir
# ****************
#
# 71
# ****************
#
# spotify:track:6dr7ekfhlbquvsVY8D7gyk

# %% [markdown]
# ### Getting features for one song

# %%
sp.audio_features(song["tracks"]["items"][0]["uri"])[0]
# Out:
# {'danceability': 0.701,
#  'energy': 0.425,
#  'key': 7,
#  'loudness': -10.965,
#  'mode': 1,
#  'speechiness': 0.375,
#  'acousticness': 0.328,
#  'instrumentalness': 0.13,
#  'liveness': 0.1,
#  'valence': 0.562,
#  'tempo': 135.128,
#  'type': 'audio_features',
#  'id': '2Fxmhks0bxGSBdJ92vM42m',
#  'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m',
#  'track_href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Fxmhks0bxGSBdJ92vM42m',
#  'duration_ms': 194088,
#  'time_signature': 4}

# %% [markdown]
# #### Building Dataframe for audio features

# %%
#my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

list_of_songs=[]
for index in range(1,len(song["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(song["tracks"]["items"][index]["uri"])[0])
pd.DataFrame(list_of_songs)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.792  0.3200    0   -16.387     0       0.3880      0.204000
# 1          0.612  0.7970    1    -3.648     1       0.4480      0.064000
# 2          0.701  0.4250    7   -10.965     1       0.3750      0.328000
# 3          0.563  0.8140    7    -4.219     0       0.0558      0.009830
# 4          0.670  0.4530    0   -11.265     1       0.2950      0.252000
# 5          0.701  0.4250    7   -10.965     1       0.3750      0.328000
# 6          0.698  0.3230    5    -9.980     1       0.1780      0.914000
# 7          0.582  0.8290    2    -5.688     1       0.0465      0.000517
# 8          0.656  0.4650    0   -12.132     1       0.0311      0.368000
# 9          0.474  0.9480    3    -2.592     1       0.1220      0.022300
# 10         0.695  0.7790    2    -5.975     1       0.2570      0.196000
# 11         0.811  0.7480    1   -10.298     1       0.0682      0.553000
# 12         0.698  0.4290    0    -9.246     0       0.0416      0.148000
# 13         0.722  0.7470    2    -3.483     1       0.0509      0.024900
# 14         0.807  0.8930   11    -3.745     0       0.0347      0.045100
# 15         0.643  0.7860    0    -3.976     1       0.0302      0.002550
# 16         0.700  0.6930    5    -5.092     1       0.2010      0.129000
# 17         0.695  0.7790    2    -5.975     1       0.2570      0.196000
# 18         0.652  0.5160   10    -7.748     0       0.0426      0.062200
# 19         0.612  0.7970    1    -3.648     1       0.4480      0.064000
# 20         0.736  0.4680    3    -8.572     0       0.1950      0.110000
# 21         0.613  0.9510    9    -2.305     0       0.2610      0.003760
# 22         0.526  0.6390    7    -6.140     1       0.1040      0.010600
# 23         0.575  0.8430    2    -4.402     1       0.0518      0.000743
# 24         0.847  0.4910    4    -8.025     0       0.4360      0.386000
# 25         0.692  0.6230    7   -11.172     1       0.2880      0.030300
# 26         0.585  0.7170    2    -5.055     1       0.0426      0.009700
# 27         0.830  0.4050    1    -8.484     1       0.4110      0.015800
# 28         0.758  0.2940    9    -9.113     0       0.0459      0.829000
# 29         0.516  0.5870    2    -5.756     1       0.0258      0.231000
# 30         0.697  0.4280    0    -9.252     0       0.0417      0.148000
# 31         0.678  0.8340    5    -6.284     0       0.0796      0.000292
# 32         0.612  0.5210   10    -7.137     1       0.0331      0.519000
# 33         0.927  0.3800    0   -11.743     0       0.0799      0.664000
# 34         0.764  0.4880    5    -6.017     1       0.0396      0.166000
# 35         0.785  0.6710   11    -7.108     0       0.0505      0.448000
# 36         0.604  0.5640    7    -6.875     1       0.2400      0.031600
# 37         0.869  0.6310    7    -5.985     0       0.0518      0.172000
# 38         0.829  0.3270    0   -11.346     0       0.1040      0.040200
# 39         0.950  0.3540    7   -10.407     0       0.4710      0.209000
# 40         0.677  0.7620    7    -5.994     0       0.0556      0.000915
# 41         0.431  0.9280    9    -7.779     1       0.0499      0.004810
# 42         0.554  0.1080    7   -19.039     0       0.0684      0.983000
# 43         0.457  0.7910    7    -5.863     1       0.1440      0.003160
# 44         0.173  0.9260    2    -4.027     1       0.1320      0.000713
# 45         0.480  0.6040   11    -5.503     0       0.1770      0.144000
# 46         0.500  0.9160    9   -12.501     1       0.1920      0.003590
# 47         0.601  0.9670    3    -1.560     0       0.1600      0.029700
# 48         0.725  0.0524    7   -30.335     0       0.1020      0.979000
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.955000    0.1060   0.5900  135.000  audio_features
# 1           0.000000    0.2570   0.3580   81.086  audio_features
# 2           0.130000    0.1000   0.5620  135.128  audio_features
# 3           0.043700    0.0732   0.7960  140.615  audio_features
# 4           0.330000    0.1170   0.6800  135.055  audio_features
# 5           0.130000    0.1000   0.5620  135.128  audio_features
# 6           0.037000    0.0991   0.6700  135.069  audio_features
# 7           0.000000    0.2660   0.8670  130.969  audio_features
# 8           0.000000    0.1550   0.7780   96.930  audio_features
# 9           0.000000    0.4300   0.6110  146.460  audio_features
# 10          0.000000    0.1100   0.7040  142.175  audio_features
# 11          0.000000    0.1100   0.8830  108.816  audio_features
# 12          0.691000    0.1010   0.5400  134.946  audio_features
# 13          0.000005    0.1970   0.3430   95.866  audio_features
# 14          0.000028    0.3660   0.5370  126.011  audio_features
# 15          0.000000    0.0462   0.5200  107.005  audio_features
# 16          0.000000    0.2320   0.4750  146.109  audio_features
# 17          0.000000    0.1100   0.7040  142.175  audio_features
# 18          0.000006    0.1200   0.3420   91.975  audio_features
# 19          0.000000    0.2570   0.3580   81.086  audio_features
# 20          0.000000    0.1070   0.4170   80.505  audio_features
# 21          0.000000    0.0774   0.9300  104.427  audio_features
# 22          0.000022    0.1200   0.7170  135.012  audio_features
# 23          0.000000    0.3150   0.8430  130.982  audio_features
# 24          0.000067    0.1190   0.6230  139.947  audio_features
# 25          0.000001    0.0958   0.3840  134.987  audio_features
# 26          0.031300    0.0952   0.7010  174.019  audio_features
# 27          0.000009    0.2410   0.1880  147.070  audio_features
# 28          0.000009    0.0981   0.3480  120.041  audio_features
# 29          0.000000    0.1080   0.2370   78.024  audio_features
# 30          0.668000    0.1010   0.5230  134.954  audio_features
# 31          0.000130    0.1170   0.4210  135.031  audio_features
# 32          0.000000    0.1660   0.3680   92.988  audio_features
# 33          0.875000    0.0945   0.5450  135.040  audio_features
# 34          0.000000    0.0979   0.2370  124.923  audio_features
# 35          0.000018    0.2250   0.5880  124.899  audio_features
# 36          0.000005    0.5850   0.8720  135.973  audio_features
# 37          0.000009    0.0671   0.6460  135.027  audio_features
# 38          0.545000    0.1050   0.7230  135.984  audio_features
# 39          0.071900    0.0570   0.4210  132.003  audio_features
# 40          0.381000    0.0966   0.7360  135.989  audio_features
# 41          0.000015    0.0473   0.4700   92.493  audio_features
# 42          0.937000    0.1010   0.0806  135.625  audio_features
# 43          0.001040    0.0670   0.5330  145.048  audio_features
# 44          0.043000    0.2910   0.0703  201.231  audio_features
# 45          0.000000    0.5370   0.4990  112.748  audio_features
# 46          0.000000    0.2100   0.4530  171.924  audio_features
# 47          0.000000    0.2600   0.4820  106.025  audio_features
# 48          0.935000    0.0943   0.1850  140.028  audio_features
#
#                         id                                   uri  \
# 0   2ktuJSnA0K4YwRZOKYCWl6  spotify:track:2ktuJSnA0K4YwRZOKYCWl6
# 1   3IaAYtmN8T0YIYVqnxNnVz  spotify:track:3IaAYtmN8T0YIYVqnxNnVz
# 2   6Pb9sdCx4rEl9ynAysZdMP  spotify:track:6Pb9sdCx4rEl9ynAysZdMP
# 3   0iM1Ioz4N4p7MU1DKyqsov  spotify:track:0iM1Ioz4N4p7MU1DKyqsov
# 4   3yNZ5r3LKfdmjoS3gkhUCT  spotify:track:3yNZ5r3LKfdmjoS3gkhUCT
# 5   1fLP2a8rubLRbXkojN98PS  spotify:track:1fLP2a8rubLRbXkojN98PS
# 6   1qOsHMitiWT4Zhx9ICzmjW  spotify:track:1qOsHMitiWT4Zhx9ICzmjW
# 7   0KqyBk4aVT88TEqBIC8mAP  spotify:track:0KqyBk4aVT88TEqBIC8mAP
# 8   4FoRp17jtblWkNCfPe9QEU  spotify:track:4FoRp17jtblWkNCfPe9QEU
# 9   78ML3F5Lz3KiNkpnFAaR3q  spotify:track:78ML3F5Lz3KiNkpnFAaR3q
# 10  1VQKKey9XgeYOm6rd1Aje8  spotify:track:1VQKKey9XgeYOm6rd1Aje8
# 11  3gZoHbFt5W3HltDGcnbDrD  spotify:track:3gZoHbFt5W3HltDGcnbDrD
# 12  2FH0jT9o0mz71s7AtMkAa4  spotify:track:2FH0jT9o0mz71s7AtMkAa4
# 13  4KVVy0GeXO03ni8Cv4SWk8  spotify:track:4KVVy0GeXO03ni8Cv4SWk8
# 14  3rmo8F54jFF8OgYsqTxm5d  spotify:track:3rmo8F54jFF8OgYsqTxm5d
# 15  760frpppJAxqsVBuiOt1yL  spotify:track:760frpppJAxqsVBuiOt1yL
# 16  4727RsuKMuY09HnC1ZD6yt  spotify:track:4727RsuKMuY09HnC1ZD6yt
# 17  7vLzU22xRA0pz9A8Ch1NNl  spotify:track:7vLzU22xRA0pz9A8Ch1NNl
# 18  0iXlgib8Sp7tU0tRdoUJYg  spotify:track:0iXlgib8Sp7tU0tRdoUJYg
# 19  5SpWTzTFzy2UiZWaEWCHWn  spotify:track:5SpWTzTFzy2UiZWaEWCHWn
# 20  5w4enr0FN8ZTwxmfnACz2f  spotify:track:5w4enr0FN8ZTwxmfnACz2f
# 21  0c5mtgPNP2jBk9fdVtZ3lf  spotify:track:0c5mtgPNP2jBk9fdVtZ3lf
# 22  3UCQwTclMnDYtS0uVjNTGO  spotify:track:3UCQwTclMnDYtS0uVjNTGO
# 23  5R4UtkoueIomI2z3Ei8B38  spotify:track:5R4UtkoueIomI2z3Ei8B38
# 24  7emJRAhUHhLtBtvzjDpjMC  spotify:track:7emJRAhUHhLtBtvzjDpjMC
# 25  7ER1r3QQOPfjj3x1UCa5pq  spotify:track:7ER1r3QQOPfjj3x1UCa5pq
# 26  5bnPew0sFrsFDUrkvVezRS  spotify:track:5bnPew0sFrsFDUrkvVezRS
# 27  5TvdhNXoHbeGeWtjCYhFuy  spotify:track:5TvdhNXoHbeGeWtjCYhFuy
# 28  1zQ2PdP4hpA9gaWiaMMoJy  spotify:track:1zQ2PdP4hpA9gaWiaMMoJy
# 29  0otmxJEwq9JI1CidrcYEq4  spotify:track:0otmxJEwq9JI1CidrcYEq4
# 30  4LzDR9ArSfr065cLQgpuba  spotify:track:4LzDR9ArSfr065cLQgpuba
# 31  3pR7bepkdYWYPeakBlh3WU  spotify:track:3pR7bepkdYWYPeakBlh3WU
# 32  6BZuf8iLTI18rN8L8WarzL  spotify:track:6BZuf8iLTI18rN8L8WarzL
# 33  1EuiDAGGub3PrpvVyabQH6  spotify:track:1EuiDAGGub3PrpvVyabQH6
# 34  34LbYwWS8Vxr6dsdZ64OXd  spotify:track:34LbYwWS8Vxr6dsdZ64OXd
# 35  1O8BgvuH9SMVddb3MQINwp  spotify:track:1O8BgvuH9SMVddb3MQINwp
# 36  6tRLfrfy692qlbT2cECgQS  spotify:track:6tRLfrfy692qlbT2cECgQS
# 37  66wi6NRfwsula1n68bJEod  spotify:track:66wi6NRfwsula1n68bJEod
# 38  4I1ypegnI8R0HlsAF5rZYn  spotify:track:4I1ypegnI8R0HlsAF5rZYn
# 39  2pliryM9cTnl6ov1gSeUWi  spotify:track:2pliryM9cTnl6ov1gSeUWi
# 40  22QpE67BB819wfq63IWWg8  spotify:track:22QpE67BB819wfq63IWWg8
# 41  5IGPVZnHthItuYm9hPAclA  spotify:track:5IGPVZnHthItuYm9hPAclA
# 42  4MClHPCWt88zdf14ztJnAz  spotify:track:4MClHPCWt88zdf14ztJnAz
# 43  5asn6PSAQN0mbmRV7FquIy  spotify:track:5asn6PSAQN0mbmRV7FquIy
# 44  75rctYH1J87zkJ51c4cxaq  spotify:track:75rctYH1J87zkJ51c4cxaq
# 45  3AeemxsZeLT9GXZJZlPc1U  spotify:track:3AeemxsZeLT9GXZJZlPc1U
# 46  5D6IIoEAfIPgYYhcR8INFV  spotify:track:5D6IIoEAfIPgYYhcR8INFV
# 47  5DumPcJlq92SLNjAWiZW93  spotify:track:5DumPcJlq92SLNjAWiZW93
# 48  1IWuiJ7X8zaPmK9NiL0lH6  spotify:track:1IWuiJ7X8zaPmK9NiL0lH6
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/2ktuJSnA0K4Y...
# 1   https://api.spotify.com/v1/tracks/3IaAYtmN8T0Y...
# 2   https://api.spotify.com/v1/tracks/6Pb9sdCx4rEl...
# 3   https://api.spotify.com/v1/tracks/0iM1Ioz4N4p7...
# 4   https://api.spotify.com/v1/tracks/3yNZ5r3LKfdm...
# 5   https://api.spotify.com/v1/tracks/1fLP2a8rubLR...
# 6   https://api.spotify.com/v1/tracks/1qOsHMitiWT4...
# 7   https://api.spotify.com/v1/tracks/0KqyBk4aVT88...
# 8   https://api.spotify.com/v1/tracks/4FoRp17jtblW...
# 9   https://api.spotify.com/v1/tracks/78ML3F5Lz3Ki...
# 10  https://api.spotify.com/v1/tracks/1VQKKey9XgeY...
# 11  https://api.spotify.com/v1/tracks/3gZoHbFt5W3H...
# 12  https://api.spotify.com/v1/tracks/2FH0jT9o0mz7...
# 13  https://api.spotify.com/v1/tracks/4KVVy0GeXO03...
# 14  https://api.spotify.com/v1/tracks/3rmo8F54jFF8...
# 15  https://api.spotify.com/v1/tracks/760frpppJAxq...
# 16  https://api.spotify.com/v1/tracks/4727RsuKMuY0...
# 17  https://api.spotify.com/v1/tracks/7vLzU22xRA0p...
# 18  https://api.spotify.com/v1/tracks/0iXlgib8Sp7t...
# 19  https://api.spotify.com/v1/tracks/5SpWTzTFzy2U...
# 20  https://api.spotify.com/v1/tracks/5w4enr0FN8ZT...
# 21  https://api.spotify.com/v1/tracks/0c5mtgPNP2jB...
# 22  https://api.spotify.com/v1/tracks/3UCQwTclMnDY...
# 23  https://api.spotify.com/v1/tracks/5R4UtkoueIom...
# 24  https://api.spotify.com/v1/tracks/7emJRAhUHhLt...
# 25  https://api.spotify.com/v1/tracks/7ER1r3QQOPfj...
# 26  https://api.spotify.com/v1/tracks/5bnPew0sFrsF...
# 27  https://api.spotify.com/v1/tracks/5TvdhNXoHbeG...
# 28  https://api.spotify.com/v1/tracks/1zQ2PdP4hpA9...
# 29  https://api.spotify.com/v1/tracks/0otmxJEwq9JI...
# 30  https://api.spotify.com/v1/tracks/4LzDR9ArSfr0...
# 31  https://api.spotify.com/v1/tracks/3pR7bepkdYWY...
# 32  https://api.spotify.com/v1/tracks/6BZuf8iLTI18...
# 33  https://api.spotify.com/v1/tracks/1EuiDAGGub3P...
# 34  https://api.spotify.com/v1/tracks/34LbYwWS8Vxr...
# 35  https://api.spotify.com/v1/tracks/1O8BgvuH9SMV...
# 36  https://api.spotify.com/v1/tracks/6tRLfrfy692q...
# 37  https://api.spotify.com/v1/tracks/66wi6NRfwsul...
# 38  https://api.spotify.com/v1/tracks/4I1ypegnI8R0...
# 39  https://api.spotify.com/v1/tracks/2pliryM9cTnl...
# 40  https://api.spotify.com/v1/tracks/22QpE67BB819...
# 41  https://api.spotify.com/v1/tracks/5IGPVZnHthIt...
# 42  https://api.spotify.com/v1/tracks/4MClHPCWt88z...
# 43  https://api.spotify.com/v1/tracks/5asn6PSAQN0m...
# 44  https://api.spotify.com/v1/tracks/75rctYH1J87z...
# 45  https://api.spotify.com/v1/tracks/3AeemxsZeLT9...
# 46  https://api.spotify.com/v1/tracks/5D6IIoEAfIPg...
# 47  https://api.spotify.com/v1/tracks/5DumPcJlq92S...
# 48  https://api.spotify.com/v1/tracks/1IWuiJ7X8zaP...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/2ktu...       149454
# 1   https://api.spotify.com/v1/audio-analysis/3IaA...       434077
# 2   https://api.spotify.com/v1/audio-analysis/6Pb9...       194088
# 3   https://api.spotify.com/v1/audio-analysis/0iM1...       157832
# 4   https://api.spotify.com/v1/audio-analysis/3yNZ...       194840
# 5   https://api.spotify.com/v1/audio-analysis/1fLP...       194088
# 6   https://api.spotify.com/v1/audio-analysis/1qOs...       193227
# 7   https://api.spotify.com/v1/audio-analysis/0Kqy...       197800
# 8   https://api.spotify.com/v1/audio-analysis/4FoR...       144170
# 9   https://api.spotify.com/v1/audio-analysis/78ML...       195373
# 10  https://api.spotify.com/v1/audio-analysis/1VQK...       221560
# 11  https://api.spotify.com/v1/audio-analysis/3gZo...       136133
# 12  https://api.spotify.com/v1/audio-analysis/2FH0...       191975
# 13  https://api.spotify.com/v1/audio-analysis/4KVV...       279133
# 14  https://api.spotify.com/v1/audio-analysis/3rmo...       230747
# 15  https://api.spotify.com/v1/audio-analysis/760f...       189227
# 16  https://api.spotify.com/v1/audio-analysis/4727...       138082
# 17  https://api.spotify.com/v1/audio-analysis/7vLz...       221560
# 18  https://api.spotify.com/v1/audio-analysis/0iXl...       150811
# 19  https://api.spotify.com/v1/audio-analysis/5SpW...       434077
# 20  https://api.spotify.com/v1/audio-analysis/5w4e...       146773
# 21  https://api.spotify.com/v1/audio-analysis/0c5m...       188817
# 22  https://api.spotify.com/v1/audio-analysis/3UCQ...       191806
# 23  https://api.spotify.com/v1/audio-analysis/5R4U...       197613
# 24  https://api.spotify.com/v1/audio-analysis/7emJ...       192400
# 25  https://api.spotify.com/v1/audio-analysis/7ER1...       193361
# 26  https://api.spotify.com/v1/audio-analysis/5bnP...       181453
# 27  https://api.spotify.com/v1/audio-analysis/5Tvd...       169493
# 28  https://api.spotify.com/v1/audio-analysis/1zQ2...       183241
# 29  https://api.spotify.com/v1/audio-analysis/0otm...       225101
# 30  https://api.spotify.com/v1/audio-analysis/4LzD...       191975
# 31  https://api.spotify.com/v1/audio-analysis/3pR7...       194055
# 32  https://api.spotify.com/v1/audio-analysis/6BZu...       250000
# 33  https://api.spotify.com/v1/audio-analysis/1Eui...       154653
# 34  https://api.spotify.com/v1/audio-analysis/34Lb...       213554
# 35  https://api.spotify.com/v1/audio-analysis/1O8B...       159360
# 36  https://api.spotify.com/v1/audio-analysis/6tRL...       194062
# 37  https://api.spotify.com/v1/audio-analysis/66wi...       167908
# 38  https://api.spotify.com/v1/audio-analysis/4I1y...       135882
# 39  https://api.spotify.com/v1/audio-analysis/2pli...       156364
# 40  https://api.spotify.com/v1/audio-analysis/22Qp...       163269
# 41  https://api.spotify.com/v1/audio-analysis/5IGP...       202893
# 42  https://api.spotify.com/v1/audio-analysis/4MCl...       160333
# 43  https://api.spotify.com/v1/audio-analysis/5asn...       232085
# 44  https://api.spotify.com/v1/audio-analysis/75rc...       235640
# 45  https://api.spotify.com/v1/audio-analysis/3Aee...       214958
# 46  https://api.spotify.com/v1/audio-analysis/5D6I...       181395
# 47  https://api.spotify.com/v1/audio-analysis/5Dum...       214947
# 48  https://api.spotify.com/v1/audio-analysis/1IWu...       266571
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# 12               4
# 13               4
# 14               4
# 15               4
# 16               4
# 17               4
# 18               4
# 19               4
# 20               4
# 21               4
# 22               4
# 23               4
# 24               4
# 25               4
# 26               4
# 27               4
# 28               4
# 29               4
# 30               4
# 31               4
# 32               4
# 33               4
# 34               4
# 35               4
# 36               4
# 37               4
# 38               4
# 39               4
# 40               4
# 41               4
# 42               4
# 43               4
# 44               4
# 45               5
# 46               4
# 47               4
# 48               5

# %% [markdown]
# #### Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "2Uh5VseH92384vmM5SMUgA",market="GB")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2Uh5VseH92384vmM5SMUgA/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#      'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#      'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#        'width': 64}],
#      'name': 'Elephunk',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 215920,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10311893'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0AnSLxClEuLksOSiIYHm4G'},
#     'href': 'https://api.spotify.com/v1/tracks/0AnSLxClEuLksOSiIYHm4G',
#     'id': '0AnSLxClEuLksOSiIYHm4G',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3yI8UscZa7l6tADw4NsBCA'},
#      'href': 'https://api.spotify.com/v1/tracks/3yI8UscZa7l6tADw4NsBCA',
#      'id': '3yI8UscZa7l6tADw4NsBCA',
#      'type': 'track',
#      'uri': 'spotify:track:3yI8UscZa7l6tADw4NsBCA'},
#     'name': "Let's Get Retarded",
#     'popularity': 45,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0AnSLxClEuLksOSiIYHm4G'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#      'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#      'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#        'width': 64}],
#      'name': 'Elephunk',
#      'release_date': '2003-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 296186,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10311895'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1HWsZxKLgySrtXOi3a5Q0j'},
#     'href': 'https://api.spotify.com/v1/tracks/1HWsZxKLgySrtXOi3a5Q0j',
#     'id': '1HWsZxKLgySrtXOi3a5Q0j',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5HJTlCbUnp1G5lMrlrlBSI'},
#      'href': 'https://api.spotify.com/v1/tracks/5HJTlCbUnp1G5lMrlrlBSI',
#      'id': '5HJTlCbUnp1G5lMrlrlBSI',
#      'type': 'track',
#      'uri': 'spotify:track:5HJTlCbUnp1G5lMrlrlBSI'},
#     'name': 'Shut Up',
#     'popularity': 49,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:1HWsZxKLgySrtXOi3a5Q0j'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#      'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#      'id': '6VsJamdhvYKcnpwHAKULI0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#        'width': 64}],
#      'name': 'Monkey Business',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 213066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10500407'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ygMBIctKIAfbEBcT9065L'},
#     'href': 'https://api.spotify.com/v1/tracks/2ygMBIctKIAfbEBcT9065L',
#     'id': '2ygMBIctKIAfbEBcT9065L',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7KIbDUwumrpG5f30kEYW1v'},
#      'href': 'https://api.spotify.com/v1/tracks/7KIbDUwumrpG5f30kEYW1v',
#      'id': '7KIbDUwumrpG5f30kEYW1v',
#      'type': 'track',
#      'uri': 'spotify:track:7KIbDUwumrpG5f30kEYW1v'},
#     'name': 'Pump It',
#     'popularity': 78,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2ygMBIctKIAfbEBcT9065L'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#        'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#        'id': '1yxSLGMDHlW21z4YXirZDS',
#        'name': 'Black Eyed Peas',
#        'type': 'artist',
#        'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#      'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#      'id': '6VsJamdhvYKcnpwHAKULI0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#        'width': 64}],
#      'name': 'Monkey Business',
#      'release_date': '2005-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 326960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10500771'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/20jYtEun4dUdYZ9foaOC48'},
#     'href': 'https://api.spotify.com/v1/tracks/20jYtEun4dUdYZ9foaOC48',
#     'id': '20jYtEun4dUdYZ9foaOC48',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2WNVqZq1ujhMDlOAqBFkVv'},
#      'href': 'https://api.spotify.com/v1/tracks/2WNVqZq1ujhMDlOAqBFkVv',
#      'id': '2WNVqZq1ujhMDlOAqBFkVv',
#      'type': 'track',
#      'uri': 'spotify:track:2WNVqZq1ujhMDlOAqBFkVv'},
#     'name': 'My Humps',
#     'popularity': 71,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:20jYtEun4dUdYZ9foaOC48'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3caKTh2tJMowPiMz0cguLI'},
#      'href': 'https://api.spotify.com/v1/albums/3caKTh2tJMowPiMz0cguLI',
#      'id': '3caKTh2tJMowPiMz0cguLI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27338a33970ad21a2a1d1315875',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0238a33970ad21a2a1d1315875',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485138a33970ad21a2a1d1315875',
#        'width': 64}],
#      'name': 'Greatest Hits: My Prerogative',
#      'release_date': '2004-11-08',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:3caKTh2tJMowPiMz0cguLI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 198813,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10301005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/26nr9XnFCYWxBTIP7HyWXg'},
#     'href': 'https://api.spotify.com/v1/tracks/26nr9XnFCYWxBTIP7HyWXg',
#     'id': '26nr9XnFCYWxBTIP7HyWXg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Toxic',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4bad1a2973681814b27247b1b8fa44c69c413040?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:26nr9XnFCYWxBTIP7HyWXg'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#      'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#      'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#        'width': 64}],
#      'name': 'Blackout',
#      'release_date': '2007-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 251240,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10700609'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ic8OlLUNEATToEFU3xmaH'},
#     'href': 'https://api.spotify.com/v1/tracks/6ic8OlLUNEATToEFU3xmaH',
#     'id': '6ic8OlLUNEATToEFU3xmaH',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Gimme More',
#     'popularity': 83,
#     'preview_url': 'https://p.scdn.co/mp3-preview/933d11a18d0ec4884f4a9620f4d628a7295e8faf?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6ic8OlLUNEATToEFU3xmaH'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#      'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#      'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#        'width': 64}],
#      'name': 'Blackout',
#      'release_date': '2007-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 175466,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10700734'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5X9tIJkTHxB19SK3FtnHT5'},
#     'href': 'https://api.spotify.com/v1/tracks/5X9tIJkTHxB19SK3FtnHT5',
#     'id': '5X9tIJkTHxB19SK3FtnHT5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Freakshow',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e61ec46bc5932d79c4ea219177ba571d633d2246?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:5X9tIJkTHxB19SK3FtnHT5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#      'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#      'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#        'width': 64}],
#      'name': 'Blackout',
#      'release_date': '2007-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 212106,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10700729'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2EvwLVrnYbCZEG6Kx5DCRy'},
#     'href': 'https://api.spotify.com/v1/tracks/2EvwLVrnYbCZEG6Kx5DCRy',
#     'id': '2EvwLVrnYbCZEG6Kx5DCRy',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Piece of Me',
#     'popularity': 68,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2ece5b2602fdaa7a69643e8729d96ae9c73b19a8?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2EvwLVrnYbCZEG6Kx5DCRy'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2tve5DGwub1TtbX1khPX5j'},
#      'href': 'https://api.spotify.com/v1/albums/2tve5DGwub1TtbX1khPX5j',
#      'id': '2tve5DGwub1TtbX1khPX5j',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27354c6edd554935d73e159e199',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0254c6edd554935d73e159e199',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485154c6edd554935d73e159e199',
#        'width': 64}],
#      'name': 'Circus (Deluxe Version)',
#      'release_date': '2008-12-02',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:2tve5DGwub1TtbX1khPX5j'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 224400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10800838'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4fixebDZAVToLbUCuEloa2'},
#     'href': 'https://api.spotify.com/v1/tracks/4fixebDZAVToLbUCuEloa2',
#     'id': '4fixebDZAVToLbUCuEloa2',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Womanizer',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/40c87bb00fe6bab71f758643b2d1e598c5374410?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4fixebDZAVToLbUCuEloa2'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#      'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#      'id': '3WNxdumkSMGMJRhEgK80qx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#        'width': 64}],
#      'name': '...Baby One More Time (Digital Deluxe Version)',
#      'release_date': '1999-01-12',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3WNxdumkSMGMJRhEgK80qx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 245066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI19910452'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1UI0l2L66HJ9AtoEOlHzv4'},
#     'href': 'https://api.spotify.com/v1/tracks/1UI0l2L66HJ9AtoEOlHzv4',
#     'id': '1UI0l2L66HJ9AtoEOlHzv4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Sometimes',
#     'popularity': 70,
#     'preview_url': 'https://p.scdn.co/mp3-preview/66534231ccdd99619485b6ea4fa90987322dd812?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1UI0l2L66HJ9AtoEOlHzv4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5PmgtkodFl2Om3hMXONDll'},
#      'href': 'https://api.spotify.com/v1/albums/5PmgtkodFl2Om3hMXONDll',
#      'id': '5PmgtkodFl2Om3hMXONDll',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732aa20611c7fb964a74ab01a6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022aa20611c7fb964a74ab01a6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512aa20611c7fb964a74ab01a6',
#        'width': 64}],
#      'name': 'Oops!... I Did It Again',
#      'release_date': '2000-05-16',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5PmgtkodFl2Om3hMXONDll'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 211160,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10000100'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6naxalmIoLFWR0siv8dnQQ'},
#     'href': 'https://api.spotify.com/v1/tracks/6naxalmIoLFWR0siv8dnQQ',
#     'id': '6naxalmIoLFWR0siv8dnQQ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Oops!...I Did It Again',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7fb86827422540ad01f65870375fef055412f034?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6naxalmIoLFWR0siv8dnQQ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#        'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#        'id': '26dSoYclwsYLMAKD3tpOr4',
#        'name': 'Britney Spears',
#        'type': 'artist',
#        'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#      'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#      'id': '3WNxdumkSMGMJRhEgK80qx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#        'width': 64}],
#      'name': '...Baby One More Time (Digital Deluxe Version)',
#      'release_date': '1999-01-12',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3WNxdumkSMGMJRhEgK80qx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'disc_number': 1,
#     'duration_ms': 211066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI19810404'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3MjUtNVVq3C8Fn0MP3zhXa'},
#     'href': 'https://api.spotify.com/v1/tracks/3MjUtNVVq3C8Fn0MP3zhXa',
#     'id': '3MjUtNVVq3C8Fn0MP3zhXa',
#     'is_local': False,
#     'is_playable': True,
#     'name': '...Baby One More Time',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/da2134a161f1cb34d17c2d6d7e77cc93d1c1e6f7?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3MjUtNVVq3C8Fn0MP3zhXa'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7K5qlneuWF1CcY6ERzwkLB'},
#      'href': 'https://api.spotify.com/v1/albums/7K5qlneuWF1CcY6ERzwkLB',
#      'id': '7K5qlneuWF1CcY6ERzwkLB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273186b235052f031900c5cb282',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02186b235052f031900c5cb282',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851186b235052f031900c5cb282',
#        'width': 64}],
#      'name': "'N Sync UK Version",
#      'release_date': '1997',
#      'release_date_precision': 'year',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7K5qlneuWF1CcY6ERzwkLB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 209400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEA819700002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/73q3FpQVXWk5eSUnyo83E4'},
#     'href': 'https://api.spotify.com/v1/tracks/73q3FpQVXWk5eSUnyo83E4',
#     'id': '73q3FpQVXWk5eSUnyo83E4',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Tearin' up My Heart - Radio Edit",
#     'popularity': 67,
#     'preview_url': 'https://p.scdn.co/mp3-preview/cce95b757e13948b173ab4be1fa1e214660eafd2?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:73q3FpQVXWk5eSUnyo83E4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7K5qlneuWF1CcY6ERzwkLB'},
#      'href': 'https://api.spotify.com/v1/albums/7K5qlneuWF1CcY6ERzwkLB',
#      'id': '7K5qlneuWF1CcY6ERzwkLB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273186b235052f031900c5cb282',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02186b235052f031900c5cb282',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851186b235052f031900c5cb282',
#        'width': 64}],
#      'name': "'N Sync UK Version",
#      'release_date': '1997',
#      'release_date_precision': 'year',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7K5qlneuWF1CcY6ERzwkLB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 200440,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEA819600477'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/221LRlPHPuevgE1tuUlof9'},
#     'href': 'https://api.spotify.com/v1/tracks/221LRlPHPuevgE1tuUlof9',
#     'id': '221LRlPHPuevgE1tuUlof9',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'I Want You Back - Radio Edit',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/eee3b05f721b771ce0934a9913e6d0ff83305856?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:221LRlPHPuevgE1tuUlof9'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7MNoY9pyL6QnnVNeV3XfVR'},
#      'href': 'https://api.spotify.com/v1/albums/7MNoY9pyL6QnnVNeV3XfVR',
#      'id': '7MNoY9pyL6QnnVNeV3XfVR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27377d7eb27ad62530422db5b8e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0277d7eb27ad62530422db5b8e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485177d7eb27ad62530422db5b8e',
#        'width': 64}],
#      'name': 'Greatest Hits',
#      'release_date': '2005-10-21',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:7MNoY9pyL6QnnVNeV3XfVR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 199640,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10000001'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2yiZyjMEByt9sJBZWnWaDR'},
#     'href': 'https://api.spotify.com/v1/tracks/2yiZyjMEByt9sJBZWnWaDR',
#     'id': '2yiZyjMEByt9sJBZWnWaDR',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bye Bye Bye',
#     'popularity': 56,
#     'preview_url': 'https://p.scdn.co/mp3-preview/26d31ed79b698d064131a219c69aa3f795b91f01?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2yiZyjMEByt9sJBZWnWaDR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5hMd4vAfSUT1cbYCnRUako'},
#      'href': 'https://api.spotify.com/v1/albums/5hMd4vAfSUT1cbYCnRUako',
#      'id': '5hMd4vAfSUT1cbYCnRUako',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fceb9d92981970dbeea23257',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fceb9d92981970dbeea23257',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fceb9d92981970dbeea23257',
#        'width': 64}],
#      'name': 'No Strings Attached',
#      'release_date': '2000-03-21',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5hMd4vAfSUT1cbYCnRUako'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 191040,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10000043'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/35zGjsxI020C2NPKp2fzS7'},
#     'href': 'https://api.spotify.com/v1/tracks/35zGjsxI020C2NPKp2fzS7',
#     'id': '35zGjsxI020C2NPKp2fzS7',
#     'is_local': False,
#     'is_playable': True,
#     'name': "It's Gonna Be Me",
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/8d77d3139230f7aa3f9d1250d3c2290af35ad73b?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:35zGjsxI020C2NPKp2fzS7'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#        'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#        'id': '6Ff53KvcvAj5U7Z1vojB5o',
#        'name': '*NSYNC',
#        'type': 'artist',
#        'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5hMd4vAfSUT1cbYCnRUako'},
#      'href': 'https://api.spotify.com/v1/albums/5hMd4vAfSUT1cbYCnRUako',
#      'id': '5hMd4vAfSUT1cbYCnRUako',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fceb9d92981970dbeea23257',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fceb9d92981970dbeea23257',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fceb9d92981970dbeea23257',
#        'width': 64}],
#      'name': 'No Strings Attached',
#      'release_date': '2000-03-21',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:5hMd4vAfSUT1cbYCnRUako'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'disc_number': 1,
#     'duration_ms': 228973,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10000046'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3okIKaE45eGIEgnfKYa8F2'},
#     'href': 'https://api.spotify.com/v1/tracks/3okIKaE45eGIEgnfKYa8F2',
#     'id': '3okIKaE45eGIEgnfKYa8F2',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'No Strings Attached',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a12822f236003d906d13de02974d2aa32722731c?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3okIKaE45eGIEgnfKYa8F2'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'},
#        'href': 'https://api.spotify.com/v1/artists/5rSXSAkZ67PYJSvpUpkOr7',
#        'id': '5rSXSAkZ67PYJSvpUpkOr7',
#        'name': 'Backstreet Boys',
#        'type': 'artist',
#        'uri': 'spotify:artist:5rSXSAkZ67PYJSvpUpkOr7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1NslKOZobWxINFaFkLol3r'},
#      'href': 'https://api.spotify.com/v1/albums/1NslKOZobWxINFaFkLol3r',
#      'id': '1NslKOZobWxINFaFkLol3r',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c2f0d820b1113f9a243fb973',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c2f0d820b1113f9a243fb973',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c2f0d820b1113f9a243fb973',
#        'width': 64}],
#      'name': 'The Hits--Chapter One',
#      'release_date': '2001-10-23',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:1NslKOZobWxINFaFkLol3r'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'},
#       'href': 'https://api.spotify.com/v1/artists/5rSXSAkZ67PYJSvpUpkOr7',
#       'id': '5rSXSAkZ67PYJSvpUpkOr7',
#       'name': 'Backstreet Boys',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rSXSAkZ67PYJSvpUpkOr7'}],
#     'disc_number': 1,
#     'duration_ms': 286306,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI19710084'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3tH03v5SIWaglfE3rzXzeB'},
#     'href': 'https://api.spotify.com/v1/tracks/3tH03v5SIWaglfE3rzXzeB',
#     'id': '3tH03v5SIWaglfE3rzXzeB',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5WTxbyWTpoqhdxEN2szOnl'},
#      'href': 'https://api.spotify.com/v1/tracks/5WTxbyWTpoqhdxEN2szOnl',
#      'id': '5WTxbyWTpoqhdxEN2szOnl',
#      'type': 'track',
#      'uri': 'spotify:track:5WTxbyWTpoqhdxEN2szOnl'},
#     'name': "Everybody (Backstreet's Back) - Extended Version",
#     'popularity': 64,
# ...
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#        'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#        'id': '5pKCCKE2ajJHZ9KAiaK11H',
#        'name': 'Rihanna',
#        'type': 'artist',
#        'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4FyGpObwABjn0o8Tdp7AZz'},
#      'href': 'https://api.spotify.com/v1/albums/4FyGpObwABjn0o8Tdp7AZz',
#      'id': '4FyGpObwABjn0o8Tdp7AZz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b21609e1a2d7c1b7ba8efae2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b21609e1a2d7c1b7ba8efae2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b21609e1a2d7c1b7ba8efae2',
#        'width': 64}],
#      'name': 'Music Of The Sun',
#      'release_date': '2005-08-29',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4FyGpObwABjn0o8Tdp7AZz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5pKCCKE2ajJHZ9KAiaK11H'},
#       'href': 'https://api.spotify.com/v1/artists/5pKCCKE2ajJHZ9KAiaK11H',
#       'id': '5pKCCKE2ajJHZ9KAiaK11H',
#       'name': 'Rihanna',
#       'type': 'artist',
#       'uri': 'spotify:artist:5pKCCKE2ajJHZ9KAiaK11H'}],
#     'disc_number': 1,
#     'duration_ms': 246960,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR20500331'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4TsmezEQVSZNNPv5RJ65Ov'},
#     'href': 'https://api.spotify.com/v1/tracks/4TsmezEQVSZNNPv5RJ65Ov',
#     'id': '4TsmezEQVSZNNPv5RJ65Ov',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Pon de Replay',
#     'popularity': 80,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4TsmezEQVSZNNPv5RJ65Ov'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6S0dmVVn4udvppDhZIWxCr'},
#        'href': 'https://api.spotify.com/v1/artists/6S0dmVVn4udvppDhZIWxCr',
#        'id': '6S0dmVVn4udvppDhZIWxCr',
#        'name': 'Sean Kingston',
#        'type': 'artist',
#        'uri': 'spotify:artist:6S0dmVVn4udvppDhZIWxCr'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/71clfVkkopYLrgweVj2cow'},
#      'href': 'https://api.spotify.com/v1/albums/71clfVkkopYLrgweVj2cow',
#      'id': '71clfVkkopYLrgweVj2cow',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736a45d20e414fbc456ecea553',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026a45d20e414fbc456ecea553',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516a45d20e414fbc456ecea553',
#        'width': 64}],
#      'name': 'Beautiful Girls',
#      'release_date': '2007-07-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:71clfVkkopYLrgweVj2cow'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6S0dmVVn4udvppDhZIWxCr'},
#       'href': 'https://api.spotify.com/v1/artists/6S0dmVVn4udvppDhZIWxCr',
#       'id': '6S0dmVVn4udvppDhZIWxCr',
#       'name': 'Sean Kingston',
#       'type': 'artist',
#       'uri': 'spotify:artist:6S0dmVVn4udvppDhZIWxCr'}],
#     'disc_number': 1,
#     'duration_ms': 225373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10701781'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1hGy2eLcmC8eKx7qr1tOqx'},
#     'href': 'https://api.spotify.com/v1/tracks/1hGy2eLcmC8eKx7qr1tOqx',
#     'id': '1hGy2eLcmC8eKx7qr1tOqx',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Beautiful Girls',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/149a2a28b7acbe31096d9f3cb4618ef08926c8b2?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1hGy2eLcmC8eKx7qr1tOqx'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TImkz4nPqjegtVSMZnMRq'},
#        'href': 'https://api.spotify.com/v1/artists/0TImkz4nPqjegtVSMZnMRq',
#        'id': '0TImkz4nPqjegtVSMZnMRq',
#        'name': 'TLC',
#        'type': 'artist',
#        'uri': 'spotify:artist:0TImkz4nPqjegtVSMZnMRq'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1CvjjpvqVMoyprsf74bpYW'},
#      'href': 'https://api.spotify.com/v1/albums/1CvjjpvqVMoyprsf74bpYW',
#      'id': '1CvjjpvqVMoyprsf74bpYW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27361ffafd5e31a37336531cf95',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0261ffafd5e31a37336531cf95',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485161ffafd5e31a37336531cf95',
#        'width': 64}],
#      'name': 'Fanmail',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:1CvjjpvqVMoyprsf74bpYW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TImkz4nPqjegtVSMZnMRq'},
#       'href': 'https://api.spotify.com/v1/artists/0TImkz4nPqjegtVSMZnMRq',
#       'id': '0TImkz4nPqjegtVSMZnMRq',
#       'name': 'TLC',
#       'type': 'artist',
#       'uri': 'spotify:artist:0TImkz4nPqjegtVSMZnMRq'}],
#     'disc_number': 1,
#     'duration_ms': 214400,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLF29900479'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1KGi9sZVMeszgZOWivFpxs'},
#     'href': 'https://api.spotify.com/v1/tracks/1KGi9sZVMeszgZOWivFpxs',
#     'id': '1KGi9sZVMeszgZOWivFpxs',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'No Scrubs',
#     'popularity': 81,
#     'preview_url': 'https://p.scdn.co/mp3-preview/69daa711bddd8fe7aa9acf17106ca85cf1ccfa14?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:1KGi9sZVMeszgZOWivFpxs'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gBjLmx6zQnFGQJCAQpRgw'},
#        'href': 'https://api.spotify.com/v1/artists/2gBjLmx6zQnFGQJCAQpRgw',
#        'id': '2gBjLmx6zQnFGQJCAQpRgw',
#        'name': 'Nelly',
#        'type': 'artist',
#        'uri': 'spotify:artist:2gBjLmx6zQnFGQJCAQpRgw'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1kh5XByhI0DDWV7m9kddr0'},
#      'href': 'https://api.spotify.com/v1/albums/1kh5XByhI0DDWV7m9kddr0',
#      'id': '1kh5XByhI0DDWV7m9kddr0',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273367bb42d6ff622f44303bae5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02367bb42d6ff622f44303bae5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851367bb42d6ff622f44303bae5',
#        'width': 64}],
#      'name': 'Nellyville',
#      'release_date': '2002-06-25',
#      'release_date_precision': 'day',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:1kh5XByhI0DDWV7m9kddr0'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gBjLmx6zQnFGQJCAQpRgw'},
#       'href': 'https://api.spotify.com/v1/artists/2gBjLmx6zQnFGQJCAQpRgw',
#       'id': '2gBjLmx6zQnFGQJCAQpRgw',
#       'name': 'Nelly',
#       'type': 'artist',
#       'uri': 'spotify:artist:2gBjLmx6zQnFGQJCAQpRgw'}],
#     'disc_number': 1,
#     'duration_ms': 228240,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUR10200371'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5FLctoy4mpCxLJ1QPneTOV'},
#     'href': 'https://api.spotify.com/v1/tracks/5FLctoy4mpCxLJ1QPneTOV',
#     'id': '5FLctoy4mpCxLJ1QPneTOV',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/04KTF78FFg8sOHC1BADqbY'},
#      'href': 'https://api.spotify.com/v1/tracks/04KTF78FFg8sOHC1BADqbY',
#      'id': '04KTF78FFg8sOHC1BADqbY',
#      'type': 'track',
#      'uri': 'spotify:track:04KTF78FFg8sOHC1BADqbY'},
#     'name': 'Hot In Herre',
#     'popularity': 59,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:5FLctoy4mpCxLJ1QPneTOV'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#        'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#        'id': '2NdeV5rLm47xAvogXrYhJX',
#        'name': 'Ciara',
#        'type': 'artist',
#        'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/71gUhKYZIWmmjqAHlY4Br3'},
#      'href': 'https://api.spotify.com/v1/albums/71gUhKYZIWmmjqAHlY4Br3',
#      'id': '71gUhKYZIWmmjqAHlY4Br3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c1e3659212de0f437bbf395e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c1e3659212de0f437bbf395e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c1e3659212de0f437bbf395e',
#        'width': 64}],
#      'name': 'Goodies',
#      'release_date': '2004-09-27',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:71gUhKYZIWmmjqAHlY4Br3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#       'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#       'id': '2NdeV5rLm47xAvogXrYhJX',
#       'name': 'Ciara',
#       'type': 'artist',
#       'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#       'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#       'id': '2wIVse2owClT7go1WT98tk',
#       'name': 'Missy Elliott',
#       'type': 'artist',
#       'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}],
#     'disc_number': 1,
#     'duration_ms': 203786,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USLF20400121'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7uKcScNXuO3MWw6LowBjW1'},
#     'href': 'https://api.spotify.com/v1/tracks/7uKcScNXuO3MWw6LowBjW1',
#     'id': '7uKcScNXuO3MWw6LowBjW1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'One, Two Step (feat. Missy Elliott)',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ebc79c6e835bd18a744307d51c942a749e3ad2ca?cid=acf6602caa5749f79900cabb94c1c3e4',
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7uKcScNXuO3MWw6LowBjW1'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-09-09T10:44:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#     'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#     'id': '22htsfsj6ksp4hr6bal4zvboa',
#     'type': 'user',
#     'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#        'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#        'id': '5YGY8feqx7naU7z4HrwZM6',
#        'name': 'Miley Cyrus',
#        'type': 'artist',
#        'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0IuHVgAvbNDJnJepuSZ8Oz'},
#      'href': 'https://api.spotify.com/v1/albums/0IuHVgAvbNDJnJepuSZ8Oz',
#      'id': '0IuHVgAvbNDJnJepuSZ8Oz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734ea6653890e297d53e93e3e0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024ea6653890e297d53e93e3e0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514ea6653890e297d53e93e3e0',
#        'width': 64}],
#      'name': 'The Time Of Our Lives (International Version)',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:0IuHVgAvbNDJnJepuSZ8Oz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#       'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#       'id': '5YGY8feqx7naU7z4HrwZM6',
#       'name': 'Miley Cyrus',
#       'type': 'artist',
#       'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#     'disc_number': 1,
#     'duration_ms': 202066,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR10924519'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3E7dfMvvCLUddWissuqMwr'},
#     'href': 'https://api.spotify.com/v1/tracks/3E7dfMvvCLUddWissuqMwr',
#     'id': '3E7dfMvvCLUddWissuqMwr',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5Q0Nhxo0l2bP3pNjpGJwV1'},
#      'href': 'https://api.spotify.com/v1/tracks/5Q0Nhxo0l2bP3pNjpGJwV1',
#      'id': '5Q0Nhxo0l2bP3pNjpGJwV1',
#      'type': 'track',
#      'uri': 'spotify:track:5Q0Nhxo0l2bP3pNjpGJwV1'},
#     'name': 'Party In The U.S.A.',
#     'popularity': 82,
#     'preview_url': None,
#     'track': True,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3E7dfMvvCLUddWissuqMwr'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/2Uh5VseH92384vmM5SMUgA/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 516}

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  516
# 100

# %%
playlist['href']
# Out:
# 'https://api.spotify.com/v1/playlists/2Uh5VseH92384vmM5SMUgA/tracks?offset=0&limit=100&market=GB&additional_types=track'

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
playlist_all = get_playlist_tracks("spotify", "2Uh5VseH92384vmM5SMUgA")

# %%
playlist_all
# Out:
# [{'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#     'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#     'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#       'width': 64}],
#     'name': 'Elephunk',
#     'release_date': '2003-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#      'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#      'id': '1yxSLGMDHlW21z4YXirZDS',
#      'name': 'Black Eyed Peas',
#      'type': 'artist',
#      'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#    'disc_number': 1,
#    'duration_ms': 215920,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR10311893'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0AnSLxClEuLksOSiIYHm4G'},
#    'href': 'https://api.spotify.com/v1/tracks/0AnSLxClEuLksOSiIYHm4G',
#    'id': '0AnSLxClEuLksOSiIYHm4G',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3yI8UscZa7l6tADw4NsBCA'},
#     'href': 'https://api.spotify.com/v1/tracks/3yI8UscZa7l6tADw4NsBCA',
#     'id': '3yI8UscZa7l6tADw4NsBCA',
#     'type': 'track',
#     'uri': 'spotify:track:3yI8UscZa7l6tADw4NsBCA'},
#    'name': "Let's Get Retarded",
#    'popularity': 45,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:0AnSLxClEuLksOSiIYHm4G'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#     'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#     'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#       'width': 64}],
#     'name': 'Elephunk',
#     'release_date': '2003-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#      'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#      'id': '1yxSLGMDHlW21z4YXirZDS',
#      'name': 'Black Eyed Peas',
#      'type': 'artist',
#      'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#    'disc_number': 1,
#    'duration_ms': 296186,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR10311895'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1HWsZxKLgySrtXOi3a5Q0j'},
#    'href': 'https://api.spotify.com/v1/tracks/1HWsZxKLgySrtXOi3a5Q0j',
#    'id': '1HWsZxKLgySrtXOi3a5Q0j',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5HJTlCbUnp1G5lMrlrlBSI'},
#     'href': 'https://api.spotify.com/v1/tracks/5HJTlCbUnp1G5lMrlrlBSI',
#     'id': '5HJTlCbUnp1G5lMrlrlBSI',
#     'type': 'track',
#     'uri': 'spotify:track:5HJTlCbUnp1G5lMrlrlBSI'},
#    'name': 'Shut Up',
#    'popularity': 49,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:1HWsZxKLgySrtXOi3a5Q0j'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#     'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#     'id': '6VsJamdhvYKcnpwHAKULI0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#       'width': 64}],
#     'name': 'Monkey Business',
#     'release_date': '2005-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#      'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#      'id': '1yxSLGMDHlW21z4YXirZDS',
#      'name': 'Black Eyed Peas',
#      'type': 'artist',
#      'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#    'disc_number': 1,
#    'duration_ms': 213066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR10500407'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2ygMBIctKIAfbEBcT9065L'},
#    'href': 'https://api.spotify.com/v1/tracks/2ygMBIctKIAfbEBcT9065L',
#    'id': '2ygMBIctKIAfbEBcT9065L',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7KIbDUwumrpG5f30kEYW1v'},
#     'href': 'https://api.spotify.com/v1/tracks/7KIbDUwumrpG5f30kEYW1v',
#     'id': '7KIbDUwumrpG5f30kEYW1v',
#     'type': 'track',
#     'uri': 'spotify:track:7KIbDUwumrpG5f30kEYW1v'},
#    'name': 'Pump It',
#    'popularity': 78,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2ygMBIctKIAfbEBcT9065L'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#     'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#     'id': '6VsJamdhvYKcnpwHAKULI0',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#       'width': 64}],
#     'name': 'Monkey Business',
#     'release_date': '2005-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#      'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#      'id': '1yxSLGMDHlW21z4YXirZDS',
#      'name': 'Black Eyed Peas',
#      'type': 'artist',
#      'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#    'disc_number': 1,
#    'duration_ms': 326960,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USIR10500771'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/20jYtEun4dUdYZ9foaOC48'},
#    'href': 'https://api.spotify.com/v1/tracks/20jYtEun4dUdYZ9foaOC48',
#    'id': '20jYtEun4dUdYZ9foaOC48',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2WNVqZq1ujhMDlOAqBFkVv'},
#     'href': 'https://api.spotify.com/v1/tracks/2WNVqZq1ujhMDlOAqBFkVv',
#     'id': '2WNVqZq1ujhMDlOAqBFkVv',
#     'type': 'track',
#     'uri': 'spotify:track:2WNVqZq1ujhMDlOAqBFkVv'},
#    'name': 'My Humps',
#    'popularity': 71,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:20jYtEun4dUdYZ9foaOC48'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3caKTh2tJMowPiMz0cguLI'},
#     'href': 'https://api.spotify.com/v1/albums/3caKTh2tJMowPiMz0cguLI',
#     'id': '3caKTh2tJMowPiMz0cguLI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27338a33970ad21a2a1d1315875',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0238a33970ad21a2a1d1315875',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485138a33970ad21a2a1d1315875',
#       'width': 64}],
#     'name': 'Greatest Hits: My Prerogative',
#     'release_date': '2004-11-08',
#     'release_date_precision': 'day',
#     'total_tracks': 27,
#     'type': 'album',
#     'uri': 'spotify:album:3caKTh2tJMowPiMz0cguLI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#      'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#      'id': '26dSoYclwsYLMAKD3tpOr4',
#      'name': 'Britney Spears',
#      'type': 'artist',
#      'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#    'disc_number': 1,
#    'duration_ms': 198813,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI10301005'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/26nr9XnFCYWxBTIP7HyWXg'},
#    'href': 'https://api.spotify.com/v1/tracks/26nr9XnFCYWxBTIP7HyWXg',
#    'id': '26nr9XnFCYWxBTIP7HyWXg',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Toxic',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/4bad1a2973681814b27247b1b8fa44c69c413040?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:26nr9XnFCYWxBTIP7HyWXg'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#     'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#     'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#       'width': 64}],
#     'name': 'Blackout',
#     'release_date': '2007-10-25',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#      'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#      'id': '26dSoYclwsYLMAKD3tpOr4',
#      'name': 'Britney Spears',
#      'type': 'artist',
#      'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#    'disc_number': 1,
#    'duration_ms': 251240,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI10700609'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ic8OlLUNEATToEFU3xmaH'},
#    'href': 'https://api.spotify.com/v1/tracks/6ic8OlLUNEATToEFU3xmaH',
#    'id': '6ic8OlLUNEATToEFU3xmaH',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Gimme More',
#    'popularity': 83,
#    'preview_url': 'https://p.scdn.co/mp3-preview/933d11a18d0ec4884f4a9620f4d628a7295e8faf?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6ic8OlLUNEATToEFU3xmaH'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#     'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#     'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#       'width': 64}],
#     'name': 'Blackout',
#     'release_date': '2007-10-25',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#      'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#      'id': '26dSoYclwsYLMAKD3tpOr4',
#      'name': 'Britney Spears',
#      'type': 'artist',
#      'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#    'disc_number': 1,
#    'duration_ms': 175466,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI10700734'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5X9tIJkTHxB19SK3FtnHT5'},
#    'href': 'https://api.spotify.com/v1/tracks/5X9tIJkTHxB19SK3FtnHT5',
#    'id': '5X9tIJkTHxB19SK3FtnHT5',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Freakshow',
#    'popularity': 49,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e61ec46bc5932d79c4ea219177ba571d633d2246?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:5X9tIJkTHxB19SK3FtnHT5'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#     'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#     'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#       'width': 64}],
#     'name': 'Blackout',
#     'release_date': '2007-10-25',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#      'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#      'id': '26dSoYclwsYLMAKD3tpOr4',
#      'name': 'Britney Spears',
#      'type': 'artist',
#      'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#    'disc_number': 1,
#    'duration_ms': 212106,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI10700729'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2EvwLVrnYbCZEG6Kx5DCRy'},
#    'href': 'https://api.spotify.com/v1/tracks/2EvwLVrnYbCZEG6Kx5DCRy',
#    'id': '2EvwLVrnYbCZEG6Kx5DCRy',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Piece of Me',
#    'popularity': 68,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2ece5b2602fdaa7a69643e8729d96ae9c73b19a8?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2EvwLVrnYbCZEG6Kx5DCRy'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2tve5DGwub1TtbX1khPX5j'},
#     'href': 'https://api.spotify.com/v1/albums/2tve5DGwub1TtbX1khPX5j',
#     'id': '2tve5DGwub1TtbX1khPX5j',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27354c6edd554935d73e159e199',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0254c6edd554935d73e159e199',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485154c6edd554935d73e159e199',
#       'width': 64}],
#     'name': 'Circus (Deluxe Version)',
#     'release_date': '2008-12-02',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:2tve5DGwub1TtbX1khPX5j'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#      'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#      'id': '26dSoYclwsYLMAKD3tpOr4',
#      'name': 'Britney Spears',
#      'type': 'artist',
#      'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#    'disc_number': 1,
#    'duration_ms': 224400,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI10800838'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4fixebDZAVToLbUCuEloa2'},
#    'href': 'https://api.spotify.com/v1/tracks/4fixebDZAVToLbUCuEloa2',
#    'id': '4fixebDZAVToLbUCuEloa2',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Womanizer',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/40c87bb00fe6bab71f758643b2d1e598c5374410?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4fixebDZAVToLbUCuEloa2'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#     'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#     'id': '3WNxdumkSMGMJRhEgK80qx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#       'width': 64}],
#     'name': '...Baby One More Time (Digital Deluxe Version)',
#     'release_date': '1999-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:3WNxdumkSMGMJRhEgK80qx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#      'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#      'id': '26dSoYclwsYLMAKD3tpOr4',
#      'name': 'Britney Spears',
#      'type': 'artist',
#      'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#    'disc_number': 1,
#    'duration_ms': 245066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI19910452'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1UI0l2L66HJ9AtoEOlHzv4'},
#    'href': 'https://api.spotify.com/v1/tracks/1UI0l2L66HJ9AtoEOlHzv4',
#    'id': '1UI0l2L66HJ9AtoEOlHzv4',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Sometimes',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/66534231ccdd99619485b6ea4fa90987322dd812?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1UI0l2L66HJ9AtoEOlHzv4'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5PmgtkodFl2Om3hMXONDll'},
#     'href': 'https://api.spotify.com/v1/albums/5PmgtkodFl2Om3hMXONDll',
#     'id': '5PmgtkodFl2Om3hMXONDll',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732aa20611c7fb964a74ab01a6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022aa20611c7fb964a74ab01a6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512aa20611c7fb964a74ab01a6',
#       'width': 64}],
#     'name': 'Oops!... I Did It Again',
#     'release_date': '2000-05-16',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:5PmgtkodFl2Om3hMXONDll'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#      'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#      'id': '26dSoYclwsYLMAKD3tpOr4',
#      'name': 'Britney Spears',
#      'type': 'artist',
#      'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#    'disc_number': 1,
#    'duration_ms': 211160,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI10000100'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6naxalmIoLFWR0siv8dnQQ'},
#    'href': 'https://api.spotify.com/v1/tracks/6naxalmIoLFWR0siv8dnQQ',
#    'id': '6naxalmIoLFWR0siv8dnQQ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Oops!...I Did It Again',
#    'popularity': 81,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7fb86827422540ad01f65870375fef055412f034?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6naxalmIoLFWR0siv8dnQQ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#       'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#       'id': '26dSoYclwsYLMAKD3tpOr4',
#       'name': 'Britney Spears',
#       'type': 'artist',
#       'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#     'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#     'id': '3WNxdumkSMGMJRhEgK80qx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#       'width': 64}],
#     'name': '...Baby One More Time (Digital Deluxe Version)',
#     'release_date': '1999-01-12',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:3WNxdumkSMGMJRhEgK80qx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#      'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#      'id': '26dSoYclwsYLMAKD3tpOr4',
#      'name': 'Britney Spears',
#      'type': 'artist',
#      'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#    'disc_number': 1,
#    'duration_ms': 211066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI19810404'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3MjUtNVVq3C8Fn0MP3zhXa'},
#    'href': 'https://api.spotify.com/v1/tracks/3MjUtNVVq3C8Fn0MP3zhXa',
#    'id': '3MjUtNVVq3C8Fn0MP3zhXa',
#    'is_local': False,
#    'is_playable': True,
#    'name': '...Baby One More Time',
#    'popularity': 81,
#    'preview_url': 'https://p.scdn.co/mp3-preview/da2134a161f1cb34d17c2d6d7e77cc93d1c1e6f7?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3MjUtNVVq3C8Fn0MP3zhXa'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7K5qlneuWF1CcY6ERzwkLB'},
#     'href': 'https://api.spotify.com/v1/albums/7K5qlneuWF1CcY6ERzwkLB',
#     'id': '7K5qlneuWF1CcY6ERzwkLB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273186b235052f031900c5cb282',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02186b235052f031900c5cb282',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851186b235052f031900c5cb282',
#       'width': 64}],
#     'name': "'N Sync UK Version",
#     'release_date': '1997',
#     'release_date_precision': 'year',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:7K5qlneuWF1CcY6ERzwkLB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#      'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#      'id': '6Ff53KvcvAj5U7Z1vojB5o',
#      'name': '*NSYNC',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#    'disc_number': 1,
#    'duration_ms': 209400,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEA819700002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/73q3FpQVXWk5eSUnyo83E4'},
#    'href': 'https://api.spotify.com/v1/tracks/73q3FpQVXWk5eSUnyo83E4',
#    'id': '73q3FpQVXWk5eSUnyo83E4',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Tearin' up My Heart - Radio Edit",
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cce95b757e13948b173ab4be1fa1e214660eafd2?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:73q3FpQVXWk5eSUnyo83E4'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7K5qlneuWF1CcY6ERzwkLB'},
#     'href': 'https://api.spotify.com/v1/albums/7K5qlneuWF1CcY6ERzwkLB',
#     'id': '7K5qlneuWF1CcY6ERzwkLB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273186b235052f031900c5cb282',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02186b235052f031900c5cb282',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851186b235052f031900c5cb282',
#       'width': 64}],
#     'name': "'N Sync UK Version",
#     'release_date': '1997',
#     'release_date_precision': 'year',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:7K5qlneuWF1CcY6ERzwkLB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#      'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#      'id': '6Ff53KvcvAj5U7Z1vojB5o',
#      'name': '*NSYNC',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#    'disc_number': 1,
#    'duration_ms': 200440,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DEA819600477'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/221LRlPHPuevgE1tuUlof9'},
#    'href': 'https://api.spotify.com/v1/tracks/221LRlPHPuevgE1tuUlof9',
#    'id': '221LRlPHPuevgE1tuUlof9',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'I Want You Back - Radio Edit',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/eee3b05f721b771ce0934a9913e6d0ff83305856?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:221LRlPHPuevgE1tuUlof9'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7MNoY9pyL6QnnVNeV3XfVR'},
#     'href': 'https://api.spotify.com/v1/albums/7MNoY9pyL6QnnVNeV3XfVR',
#     'id': '7MNoY9pyL6QnnVNeV3XfVR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27377d7eb27ad62530422db5b8e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0277d7eb27ad62530422db5b8e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485177d7eb27ad62530422db5b8e',
#       'width': 64}],
#     'name': 'Greatest Hits',
#     'release_date': '2005-10-21',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:7MNoY9pyL6QnnVNeV3XfVR'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#      'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#      'id': '6Ff53KvcvAj5U7Z1vojB5o',
#      'name': '*NSYNC',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#    'disc_number': 1,
#    'duration_ms': 199640,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI10000001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2yiZyjMEByt9sJBZWnWaDR'},
#    'href': 'https://api.spotify.com/v1/tracks/2yiZyjMEByt9sJBZWnWaDR',
#    'id': '2yiZyjMEByt9sJBZWnWaDR',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Bye Bye Bye',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/26d31ed79b698d064131a219c69aa3f795b91f01?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2yiZyjMEByt9sJBZWnWaDR'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5hMd4vAfSUT1cbYCnRUako'},
#     'href': 'https://api.spotify.com/v1/albums/5hMd4vAfSUT1cbYCnRUako',
#     'id': '5hMd4vAfSUT1cbYCnRUako',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fceb9d92981970dbeea23257',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fceb9d92981970dbeea23257',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fceb9d92981970dbeea23257',
#       'width': 64}],
#     'name': 'No Strings Attached',
#     'release_date': '2000-03-21',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5hMd4vAfSUT1cbYCnRUako'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#      'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#      'id': '6Ff53KvcvAj5U7Z1vojB5o',
#      'name': '*NSYNC',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#    'disc_number': 1,
#    'duration_ms': 191040,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI10000043'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/35zGjsxI020C2NPKp2fzS7'},
#    'href': 'https://api.spotify.com/v1/tracks/35zGjsxI020C2NPKp2fzS7',
#    'id': '35zGjsxI020C2NPKp2fzS7',
#    'is_local': False,
#    'is_playable': True,
#    'name': "It's Gonna Be Me",
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8d77d3139230f7aa3f9d1250d3c2290af35ad73b?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:35zGjsxI020C2NPKp2fzS7'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#       'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#       'id': '6Ff53KvcvAj5U7Z1vojB5o',
#       'name': '*NSYNC',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5hMd4vAfSUT1cbYCnRUako'},
#     'href': 'https://api.spotify.com/v1/albums/5hMd4vAfSUT1cbYCnRUako',
#     'id': '5hMd4vAfSUT1cbYCnRUako',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fceb9d92981970dbeea23257',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fceb9d92981970dbeea23257',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fceb9d92981970dbeea23257',
#       'width': 64}],
#     'name': 'No Strings Attached',
#     'release_date': '2000-03-21',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:5hMd4vAfSUT1cbYCnRUako'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Ff53KvcvAj5U7Z1vojB5o'},
#      'href': 'https://api.spotify.com/v1/artists/6Ff53KvcvAj5U7Z1vojB5o',
#      'id': '6Ff53KvcvAj5U7Z1vojB5o',
#      'name': '*NSYNC',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Ff53KvcvAj5U7Z1vojB5o'}],
#    'disc_number': 1,
#    'duration_ms': 228973,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI10000046'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3okIKaE45eGIEgnfKYa8F2'},
#    'href': 'https://api.spotify.com/v1/tracks/3okIKaE45eGIEgnfKYa8F2',
#    'id': '3okIKaE45eGIEgnfKYa8F2',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'No Strings Attached',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a12822f236003d906d13de02974d2aa32722731c?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:3okIKaE45eGIEgnfKYa8F2'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'},
#       'href': 'https://api.spotify.com/v1/artists/5rSXSAkZ67PYJSvpUpkOr7',
#       'id': '5rSXSAkZ67PYJSvpUpkOr7',
#       'name': 'Backstreet Boys',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rSXSAkZ67PYJSvpUpkOr7'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1NslKOZobWxINFaFkLol3r'},
#     'href': 'https://api.spotify.com/v1/albums/1NslKOZobWxINFaFkLol3r',
#     'id': '1NslKOZobWxINFaFkLol3r',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c2f0d820b1113f9a243fb973',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c2f0d820b1113f9a243fb973',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c2f0d820b1113f9a243fb973',
#       'width': 64}],
#     'name': 'The Hits--Chapter One',
#     'release_date': '2001-10-23',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:1NslKOZobWxINFaFkLol3r'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'},
#      'href': 'https://api.spotify.com/v1/artists/5rSXSAkZ67PYJSvpUpkOr7',
#      'id': '5rSXSAkZ67PYJSvpUpkOr7',
#      'name': 'Backstreet Boys',
#      'type': 'artist',
#      'uri': 'spotify:artist:5rSXSAkZ67PYJSvpUpkOr7'}],
#    'disc_number': 1,
#    'duration_ms': 286306,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJI19710084'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3tH03v5SIWaglfE3rzXzeB'},
#    'href': 'https://api.spotify.com/v1/tracks/3tH03v5SIWaglfE3rzXzeB',
#    'id': '3tH03v5SIWaglfE3rzXzeB',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5WTxbyWTpoqhdxEN2szOnl'},
#     'href': 'https://api.spotify.com/v1/tracks/5WTxbyWTpoqhdxEN2szOnl',
#     'id': '5WTxbyWTpoqhdxEN2szOnl',
#     'type': 'track',
#     'uri': 'spotify:track:5WTxbyWTpoqhdxEN2szOnl'},
#    'name': "Everybody (Backstreet's Back) - Extended Version",
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a20044823e99f956db51e6ebd5a0ff449b267a1d?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3tH03v5SIWaglfE3rzXzeB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-09-09T10:44:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5rSXSAkZ67PYJSvpUpkOr7'},
#       'href': 'https://api.spotify.com/v1/artists/5rSXSAkZ67PYJSvpUpkOr7',
#       'id': '5rSXSAkZ67PYJSvpUpkOr7',
#       'name': 'Backstreet Boys',
#       'type': 'artist',
#       'uri': 'spotify:artist:5rSXSAkZ67PYJSvpUpkOr7'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1NslKOZobWxINFaFkLol3r'},
#     'href': 'https://api.spotify.com/v1/albums/1NslKOZobWxINFaFkLol3r',
#     'id': '1NslKOZobWxINFaFkLol3r',
#     'images': [{'height': 640,
# ...
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/65kBPB0tVlidbZiQaFrxhb'},
#     'href': 'https://api.spotify.com/v1/albums/65kBPB0tVlidbZiQaFrxhb',
#     'id': '65kBPB0tVlidbZiQaFrxhb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27350ec484aadc4e99798c5a02b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0250ec484aadc4e99798c5a02b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485150ec484aadc4e99798c5a02b',
#       'width': 64}],
#     'name': 'Biggest Ragga Dancehall Anthems 2004',
#     'release_date': '2004',
#     'release_date_precision': 'year',
#     'total_tracks': 40,
#     'type': 'album',
#     'uri': 'spotify:album:65kBPB0tVlidbZiQaFrxhb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5VpGjLseyraVCLxc49SzWC'},
#      'href': 'https://api.spotify.com/v1/artists/5VpGjLseyraVCLxc49SzWC',
#      'id': '5VpGjLseyraVCLxc49SzWC',
#      'name': 'Nina Sky featuring Jabba',
#      'type': 'artist',
#      'uri': 'spotify:artist:5VpGjLseyraVCLxc49SzWC'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6TL5LD7Gqmo99xssJEbQpA'},
#      'href': 'https://api.spotify.com/v1/artists/6TL5LD7Gqmo99xssJEbQpA',
#      'id': '6TL5LD7Gqmo99xssJEbQpA',
#      'name': 'Jabba',
#      'type': 'artist',
#      'uri': 'spotify:artist:6TL5LD7Gqmo99xssJEbQpA'}],
#    'disc_number': 1,
#    'duration_ms': 258733,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBBZV0450853'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5fXWcDrcJe85rolTOxDrC1'},
#    'href': 'https://api.spotify.com/v1/tracks/5fXWcDrcJe85rolTOxDrC1',
#    'id': '5fXWcDrcJe85rolTOxDrC1',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Move Ya Body - Vybz Kartel Remix',
#    'popularity': 45,
#    'preview_url': 'https://p.scdn.co/mp3-preview/93fbb02f32ec6f8d515e60c456445e8f7580aaf6?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:5fXWcDrcJe85rolTOxDrC1'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-09T20:27:22Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YWxKQj2Go9CGHCp77UOyy'},
#       'href': 'https://api.spotify.com/v1/artists/0YWxKQj2Go9CGHCp77UOyy',
#       'id': '0YWxKQj2Go9CGHCp77UOyy',
#       'name': 'Fabolous',
#       'type': 'artist',
#       'uri': 'spotify:artist:0YWxKQj2Go9CGHCp77UOyy'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6umODQfij1WhoGDhc7UCL8'},
#     'href': 'https://api.spotify.com/v1/albums/6umODQfij1WhoGDhc7UCL8',
#     'id': '6umODQfij1WhoGDhc7UCL8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27332d0bc6e565d1f9c7856430c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0232d0bc6e565d1f9c7856430c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485132d0bc6e565d1f9c7856430c',
#       'width': 64}],
#     'name': "Loso's Way",
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:6umODQfij1WhoGDhc7UCL8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0YWxKQj2Go9CGHCp77UOyy'},
#      'href': 'https://api.spotify.com/v1/artists/0YWxKQj2Go9CGHCp77UOyy',
#      'id': '0YWxKQj2Go9CGHCp77UOyy',
#      'name': 'Fabolous',
#      'type': 'artist',
#      'uri': 'spotify:artist:0YWxKQj2Go9CGHCp77UOyy'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1W3FSF1BLpY3hlVIgvenLz'},
#      'href': 'https://api.spotify.com/v1/artists/1W3FSF1BLpY3hlVIgvenLz',
#      'id': '1W3FSF1BLpY3hlVIgvenLz',
#      'name': 'The-Dream',
#      'type': 'artist',
#      'uri': 'spotify:artist:1W3FSF1BLpY3hlVIgvenLz'}],
#    'disc_number': 1,
#    'duration_ms': 231573,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USUM70974662'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6c0GmyBsE7mQtrVvxJaWc3'},
#    'href': 'https://api.spotify.com/v1/tracks/6c0GmyBsE7mQtrVvxJaWc3',
#    'id': '6c0GmyBsE7mQtrVvxJaWc3',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Throw It In The Bag',
#    'popularity': 62,
#    'preview_url': None,
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:6c0GmyBsE7mQtrVvxJaWc3'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-20T11:51:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cUNRt3Ha4lnnNvPTJAIa8'},
#       'href': 'https://api.spotify.com/v1/artists/1cUNRt3Ha4lnnNvPTJAIa8',
#       'id': '1cUNRt3Ha4lnnNvPTJAIa8',
#       'name': 'Scribe',
#       'type': 'artist',
#       'uri': 'spotify:artist:1cUNRt3Ha4lnnNvPTJAIa8'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0fg7W9UZs3IOL6hyr7Toli'},
#     'href': 'https://api.spotify.com/v1/albums/0fg7W9UZs3IOL6hyr7Toli',
#     'id': '0fg7W9UZs3IOL6hyr7Toli',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27396eaa311337248185aacacc4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0296eaa311337248185aacacc4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485196eaa311337248185aacacc4',
#       'width': 64}],
#     'name': 'The Crusade',
#     'release_date': '2003-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0fg7W9UZs3IOL6hyr7Toli'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cUNRt3Ha4lnnNvPTJAIa8'},
#      'href': 'https://api.spotify.com/v1/artists/1cUNRt3Ha4lnnNvPTJAIa8',
#      'id': '1cUNRt3Ha4lnnNvPTJAIa8',
#      'name': 'Scribe',
#      'type': 'artist',
#      'uri': 'spotify:artist:1cUNRt3Ha4lnnNvPTJAIa8'}],
#    'disc_number': 1,
#    'duration_ms': 257866,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'NZDI00400012'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2DRHvVOlWg7Z3pkzn58Jrh'},
#    'href': 'https://api.spotify.com/v1/tracks/2DRHvVOlWg7Z3pkzn58Jrh',
#    'id': '2DRHvVOlWg7Z3pkzn58Jrh',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2xw91d7PWN08uioRmG2VGx'},
#     'href': 'https://api.spotify.com/v1/tracks/2xw91d7PWN08uioRmG2VGx',
#     'id': '2xw91d7PWN08uioRmG2VGx',
#     'type': 'track',
#     'uri': 'spotify:track:2xw91d7PWN08uioRmG2VGx'},
#    'name': 'Dreaming',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b9785ebb55b8651759de1cf4f9f8a69815ccb072?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2DRHvVOlWg7Z3pkzn58Jrh'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2021-09-20T11:52:16Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cUNRt3Ha4lnnNvPTJAIa8'},
#       'href': 'https://api.spotify.com/v1/artists/1cUNRt3Ha4lnnNvPTJAIa8',
#       'id': '1cUNRt3Ha4lnnNvPTJAIa8',
#       'name': 'Scribe',
#       'type': 'artist',
#       'uri': 'spotify:artist:1cUNRt3Ha4lnnNvPTJAIa8'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0fg7W9UZs3IOL6hyr7Toli'},
#     'href': 'https://api.spotify.com/v1/albums/0fg7W9UZs3IOL6hyr7Toli',
#     'id': '0fg7W9UZs3IOL6hyr7Toli',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27396eaa311337248185aacacc4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0296eaa311337248185aacacc4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485196eaa311337248185aacacc4',
#       'width': 64}],
#     'name': 'The Crusade',
#     'release_date': '2003-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0fg7W9UZs3IOL6hyr7Toli'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1cUNRt3Ha4lnnNvPTJAIa8'},
#      'href': 'https://api.spotify.com/v1/artists/1cUNRt3Ha4lnnNvPTJAIa8',
#      'id': '1cUNRt3Ha4lnnNvPTJAIa8',
#      'name': 'Scribe',
#      'type': 'artist',
#      'uri': 'spotify:artist:1cUNRt3Ha4lnnNvPTJAIa8'}],
#    'disc_number': 1,
#    'duration_ms': 223080,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'NZDI00400010'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7hlwEYdoK7d0Hz7h4pGqDe'},
#    'href': 'https://api.spotify.com/v1/tracks/7hlwEYdoK7d0Hz7h4pGqDe',
#    'id': '7hlwEYdoK7d0Hz7h4pGqDe',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1KqJ51v5Sim7BVcqOANEq6'},
#     'href': 'https://api.spotify.com/v1/tracks/1KqJ51v5Sim7BVcqOANEq6',
#     'id': '1KqJ51v5Sim7BVcqOANEq6',
#     'type': 'track',
#     'uri': 'spotify:track:1KqJ51v5Sim7BVcqOANEq6'},
#    'name': 'Not Many',
#    'popularity': 53,
#    'preview_url': 'https://p.scdn.co/mp3-preview/695043f5c66dc350f6fba9967415c82a7f487399?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:7hlwEYdoK7d0Hz7h4pGqDe'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-01-21T00:29:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4eQJIXFEujzhTVVS1gIfu5'},
#       'href': 'https://api.spotify.com/v1/artists/4eQJIXFEujzhTVVS1gIfu5',
#       'id': '4eQJIXFEujzhTVVS1gIfu5',
#       'name': 'Deee-Lite',
#       'type': 'artist',
#       'uri': 'spotify:artist:4eQJIXFEujzhTVVS1gIfu5'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4sTAgYLZy5zwqR3kT1g0oh'},
#     'href': 'https://api.spotify.com/v1/albums/4sTAgYLZy5zwqR3kT1g0oh',
#     'id': '4sTAgYLZy5zwqR3kT1g0oh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cbcb5083c56df2a557625bca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cbcb5083c56df2a557625bca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cbcb5083c56df2a557625bca',
#       'width': 64}],
#     'name': 'World Clique',
#     'release_date': '1990',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4sTAgYLZy5zwqR3kT1g0oh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4eQJIXFEujzhTVVS1gIfu5'},
#      'href': 'https://api.spotify.com/v1/artists/4eQJIXFEujzhTVVS1gIfu5',
#      'id': '4eQJIXFEujzhTVVS1gIfu5',
#      'name': 'Deee-Lite',
#      'type': 'artist',
#      'uri': 'spotify:artist:4eQJIXFEujzhTVVS1gIfu5'}],
#    'disc_number': 1,
#    'duration_ms': 231786,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USEE19687204'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2He3NOyqtLNE3RQPpeDdSb'},
#    'href': 'https://api.spotify.com/v1/tracks/2He3NOyqtLNE3RQPpeDdSb',
#    'id': '2He3NOyqtLNE3RQPpeDdSb',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Groove Is in the Heart',
#    'popularity': 66,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9f04c5adba9415770b90b9d08bf055752c1d19fd?cid=acf6602caa5749f79900cabb94c1c3e4',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:2He3NOyqtLNE3RQPpeDdSb'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2022-01-27T02:14:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#    'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#    'id': '22htsfsj6ksp4hr6bal4zvboa',
#    'type': 'user',
#    'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lLYZf9GpSq6Pf09g2N2xK'},
#       'href': 'https://api.spotify.com/v1/artists/6lLYZf9GpSq6Pf09g2N2xK',
#       'id': '6lLYZf9GpSq6Pf09g2N2xK',
#       'name': 'Wreckx-N-Effect',
#       'type': 'artist',
#       'uri': 'spotify:artist:6lLYZf9GpSq6Pf09g2N2xK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6xLyv6QON3hOuKiqRKvNOw'},
#     'href': 'https://api.spotify.com/v1/albums/6xLyv6QON3hOuKiqRKvNOw',
#     'id': '6xLyv6QON3hOuKiqRKvNOw',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27355da2569ca325d4d61c77367',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0255da2569ca325d4d61c77367',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485155da2569ca325d4d61c77367',
#       'width': 64}],
#     'name': 'Hard Or Smooth',
#     'release_date': '1992-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6xLyv6QON3hOuKiqRKvNOw'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6lLYZf9GpSq6Pf09g2N2xK'},
#      'href': 'https://api.spotify.com/v1/artists/6lLYZf9GpSq6Pf09g2N2xK',
#      'id': '6lLYZf9GpSq6Pf09g2N2xK',
#      'name': 'Wreckx-N-Effect',
#      'type': 'artist',
#      'uri': 'spotify:artist:6lLYZf9GpSq6Pf09g2N2xK'}],
#    'disc_number': 1,
#    'duration_ms': 312360,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMC19238663'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4dY4JVC0Q9CwpeZ6JAclIc'},
#    'href': 'https://api.spotify.com/v1/tracks/4dY4JVC0Q9CwpeZ6JAclIc',
#    'id': '4dY4JVC0Q9CwpeZ6JAclIc',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Rump Shaker',
#    'popularity': 59,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4dY4JVC0Q9CwpeZ6JAclIc'},
#   'video_thumbnail': {'url': None}}]

# %% [markdown]
# ##### getting the artist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
#get_artists_from_playlist("2Uh5VseH92384vmM5SMUgA")

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  516

# %%
pprint.pprint(playlist)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/2Uh5VseH92384vmM5SMUgA/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                              'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                              'id': '1yxSLGMDHlW21z4YXirZDS',
#                                              'name': 'Black Eyed Peas',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#                                 'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#                                 'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#                                             'width': 64}],
#                                 'name': 'Elephunk',
#                                 'release_date': '2003-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                    'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                    'id': '1yxSLGMDHlW21z4YXirZDS',
#                                    'name': 'Black Eyed Peas',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                       'disc_number': 1,
#                       'duration_ms': 215920,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10311893'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/0AnSLxClEuLksOSiIYHm4G'},
#                       'href': 'https://api.spotify.com/v1/tracks/0AnSLxClEuLksOSiIYHm4G',
#                       'id': '0AnSLxClEuLksOSiIYHm4G',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3yI8UscZa7l6tADw4NsBCA'},
#                                       'href': 'https://api.spotify.com/v1/tracks/3yI8UscZa7l6tADw4NsBCA',
#                                       'id': '3yI8UscZa7l6tADw4NsBCA',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:3yI8UscZa7l6tADw4NsBCA'},
#                       'name': "Let's Get Retarded",
#                       'popularity': 45,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:0AnSLxClEuLksOSiIYHm4G'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                              'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                              'id': '1yxSLGMDHlW21z4YXirZDS',
#                                              'name': 'Black Eyed Peas',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2Yx0X8CYJD0G2pvJYZcTxt'},
#                                 'href': 'https://api.spotify.com/v1/albums/2Yx0X8CYJD0G2pvJYZcTxt',
#                                 'id': '2Yx0X8CYJD0G2pvJYZcTxt',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273758ecff064882ebbf6407f3f',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02758ecff064882ebbf6407f3f',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851758ecff064882ebbf6407f3f',
#                                             'width': 64}],
#                                 'name': 'Elephunk',
#                                 'release_date': '2003-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2Yx0X8CYJD0G2pvJYZcTxt'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                    'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                    'id': '1yxSLGMDHlW21z4YXirZDS',
#                                    'name': 'Black Eyed Peas',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                       'disc_number': 1,
#                       'duration_ms': 296186,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10311895'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1HWsZxKLgySrtXOi3a5Q0j'},
#                       'href': 'https://api.spotify.com/v1/tracks/1HWsZxKLgySrtXOi3a5Q0j',
#                       'id': '1HWsZxKLgySrtXOi3a5Q0j',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5HJTlCbUnp1G5lMrlrlBSI'},
#                                       'href': 'https://api.spotify.com/v1/tracks/5HJTlCbUnp1G5lMrlrlBSI',
#                                       'id': '5HJTlCbUnp1G5lMrlrlBSI',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:5HJTlCbUnp1G5lMrlrlBSI'},
#                       'name': 'Shut Up',
#                       'popularity': 49,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:1HWsZxKLgySrtXOi3a5Q0j'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                              'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                              'id': '1yxSLGMDHlW21z4YXirZDS',
#                                              'name': 'Black Eyed Peas',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#                                 'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#                                 'id': '6VsJamdhvYKcnpwHAKULI0',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#                                             'width': 64}],
#                                 'name': 'Monkey Business',
#                                 'release_date': '2005-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                    'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                    'id': '1yxSLGMDHlW21z4YXirZDS',
#                                    'name': 'Black Eyed Peas',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                       'disc_number': 1,
#                       'duration_ms': 213066,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10500407'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/2ygMBIctKIAfbEBcT9065L'},
#                       'href': 'https://api.spotify.com/v1/tracks/2ygMBIctKIAfbEBcT9065L',
#                       'id': '2ygMBIctKIAfbEBcT9065L',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7KIbDUwumrpG5f30kEYW1v'},
#                                       'href': 'https://api.spotify.com/v1/tracks/7KIbDUwumrpG5f30kEYW1v',
#                                       'id': '7KIbDUwumrpG5f30kEYW1v',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:7KIbDUwumrpG5f30kEYW1v'},
#                       'name': 'Pump It',
#                       'popularity': 78,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:2ygMBIctKIAfbEBcT9065L'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                              'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                              'id': '1yxSLGMDHlW21z4YXirZDS',
#                                              'name': 'Black Eyed Peas',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/6VsJamdhvYKcnpwHAKULI0'},
#                                 'href': 'https://api.spotify.com/v1/albums/6VsJamdhvYKcnpwHAKULI0',
#                                 'id': '6VsJamdhvYKcnpwHAKULI0',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273c6710b4a52539506c30e5354',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02c6710b4a52539506c30e5354',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851c6710b4a52539506c30e5354',
#                                             'width': 64}],
#                                 'name': 'Monkey Business',
#                                 'release_date': '2005-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:6VsJamdhvYKcnpwHAKULI0'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#                                    'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#                                    'id': '1yxSLGMDHlW21z4YXirZDS',
#                                    'name': 'Black Eyed Peas',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#                       'disc_number': 1,
#                       'duration_ms': 326960,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USIR10500771'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/20jYtEun4dUdYZ9foaOC48'},
#                       'href': 'https://api.spotify.com/v1/tracks/20jYtEun4dUdYZ9foaOC48',
#                       'id': '20jYtEun4dUdYZ9foaOC48',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2WNVqZq1ujhMDlOAqBFkVv'},
#                                       'href': 'https://api.spotify.com/v1/tracks/2WNVqZq1ujhMDlOAqBFkVv',
#                                       'id': '2WNVqZq1ujhMDlOAqBFkVv',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:2WNVqZq1ujhMDlOAqBFkVv'},
#                       'name': 'My Humps',
#                       'popularity': 71,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:20jYtEun4dUdYZ9foaOC48'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'compilation',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3caKTh2tJMowPiMz0cguLI'},
#                                 'href': 'https://api.spotify.com/v1/albums/3caKTh2tJMowPiMz0cguLI',
#                                 'id': '3caKTh2tJMowPiMz0cguLI',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27338a33970ad21a2a1d1315875',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0238a33970ad21a2a1d1315875',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485138a33970ad21a2a1d1315875',
#                                             'width': 64}],
#                                 'name': 'Greatest Hits: My Prerogative',
#                                 'release_date': '2004-11-08',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 27,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3caKTh2tJMowPiMz0cguLI'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 198813,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10301005'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/26nr9XnFCYWxBTIP7HyWXg'},
#                       'href': 'https://api.spotify.com/v1/tracks/26nr9XnFCYWxBTIP7HyWXg',
#                       'id': '26nr9XnFCYWxBTIP7HyWXg',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Toxic',
#                       'popularity': 55,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/4bad1a2973681814b27247b1b8fa44c69c413040?cid=acf6602caa5749f79900cabb94c1c3e4',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:26nr9XnFCYWxBTIP7HyWXg'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#                                 'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#                                             'width': 64}],
#                                 'name': 'Blackout',
#                                 'release_date': '2007-10-25',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 251240,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10700609'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6ic8OlLUNEATToEFU3xmaH'},
#                       'href': 'https://api.spotify.com/v1/tracks/6ic8OlLUNEATToEFU3xmaH',
#                       'id': '6ic8OlLUNEATToEFU3xmaH',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Gimme More',
#                       'popularity': 83,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/933d11a18d0ec4884f4a9620f4d628a7295e8faf?cid=acf6602caa5749f79900cabb94c1c3e4',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:6ic8OlLUNEATToEFU3xmaH'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#                                 'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#                                             'width': 64}],
#                                 'name': 'Blackout',
#                                 'release_date': '2007-10-25',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 175466,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10700734'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5X9tIJkTHxB19SK3FtnHT5'},
#                       'href': 'https://api.spotify.com/v1/tracks/5X9tIJkTHxB19SK3FtnHT5',
#                       'id': '5X9tIJkTHxB19SK3FtnHT5',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Freakshow',
#                       'popularity': 49,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/e61ec46bc5932d79c4ea219177ba571d633d2246?cid=acf6602caa5749f79900cabb94c1c3e4',
#                       'track': True,
#                       'track_number': 7,
#                       'type': 'track',
#                       'uri': 'spotify:track:5X9tIJkTHxB19SK3FtnHT5'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1ePkYcH5ZQCb1b4tQeiEDj'},
#                                 'href': 'https://api.spotify.com/v1/albums/1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'id': '1ePkYcH5ZQCb1b4tQeiEDj',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273ca10fae7d292c52f7e8b11ca',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02ca10fae7d292c52f7e8b11ca',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851ca10fae7d292c52f7e8b11ca',
#                                             'width': 64}],
#                                 'name': 'Blackout',
#                                 'release_date': '2007-10-25',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1ePkYcH5ZQCb1b4tQeiEDj'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 212106,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10700729'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/2EvwLVrnYbCZEG6Kx5DCRy'},
#                       'href': 'https://api.spotify.com/v1/tracks/2EvwLVrnYbCZEG6Kx5DCRy',
#                       'id': '2EvwLVrnYbCZEG6Kx5DCRy',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Piece of Me',
#                       'popularity': 68,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/2ece5b2602fdaa7a69643e8729d96ae9c73b19a8?cid=acf6602caa5749f79900cabb94c1c3e4',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:2EvwLVrnYbCZEG6Kx5DCRy'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/2tve5DGwub1TtbX1khPX5j'},
#                                 'href': 'https://api.spotify.com/v1/albums/2tve5DGwub1TtbX1khPX5j',
#                                 'id': '2tve5DGwub1TtbX1khPX5j',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27354c6edd554935d73e159e199',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0254c6edd554935d73e159e199',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485154c6edd554935d73e159e199',
#                                             'width': 64}],
#                                 'name': 'Circus (Deluxe Version)',
#                                 'release_date': '2008-12-02',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 15,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:2tve5DGwub1TtbX1khPX5j'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 224400,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10800838'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/4fixebDZAVToLbUCuEloa2'},
#                       'href': 'https://api.spotify.com/v1/tracks/4fixebDZAVToLbUCuEloa2',
#                       'id': '4fixebDZAVToLbUCuEloa2',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Womanizer',
#                       'popularity': 79,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/40c87bb00fe6bab71f758643b2d1e598c5374410?cid=acf6602caa5749f79900cabb94c1c3e4',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:4fixebDZAVToLbUCuEloa2'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#                                 'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#                                 'id': '3WNxdumkSMGMJRhEgK80qx',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#                                             'width': 64}],
#                                 'name': '...Baby One More Time (Digital Deluxe '
#                                         'Version)',
#                                 'release_date': '1999-01-12',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:3WNxdumkSMGMJRhEgK80qx'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 245066,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI19910452'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1UI0l2L66HJ9AtoEOlHzv4'},
#                       'href': 'https://api.spotify.com/v1/tracks/1UI0l2L66HJ9AtoEOlHzv4',
#                       'id': '1UI0l2L66HJ9AtoEOlHzv4',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Sometimes',
#                       'popularity': 70,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/66534231ccdd99619485b6ea4fa90987322dd812?cid=acf6602caa5749f79900cabb94c1c3e4',
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:1UI0l2L66HJ9AtoEOlHzv4'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/5PmgtkodFl2Om3hMXONDll'},
#                                 'href': 'https://api.spotify.com/v1/albums/5PmgtkodFl2Om3hMXONDll',
#                                 'id': '5PmgtkodFl2Om3hMXONDll',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2732aa20611c7fb964a74ab01a6',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e022aa20611c7fb964a74ab01a6',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048512aa20611c7fb964a74ab01a6',
#                                             'width': 64}],
#                                 'name': 'Oops!... I Did It Again',
#                                 'release_date': '2000-05-16',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 12,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:5PmgtkodFl2Om3hMXONDll'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                    'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                    'id': '26dSoYclwsYLMAKD3tpOr4',
#                                    'name': 'Britney Spears',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                       'disc_number': 1,
#                       'duration_ms': 211160,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USJI10000100'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/6naxalmIoLFWR0siv8dnQQ'},
#                       'href': 'https://api.spotify.com/v1/tracks/6naxalmIoLFWR0siv8dnQQ',
#                       'id': '6naxalmIoLFWR0siv8dnQQ',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'Oops!...I Did It Again',
#                       'popularity': 81,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/7fb86827422540ad01f65870375fef055412f034?cid=acf6602caa5749f79900cabb94c1c3e4',
#                       'track': True,
#                       'track_number': 1,
#                       'type': 'track',
#                       'uri': 'spotify:track:6naxalmIoLFWR0siv8dnQQ'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/26dSoYclwsYLMAKD3tpOr4'},
#                                              'href': 'https://api.spotify.com/v1/artists/26dSoYclwsYLMAKD3tpOr4',
#                                              'id': '26dSoYclwsYLMAKD3tpOr4',
#                                              'name': 'Britney Spears',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:26dSoYclwsYLMAKD3tpOr4'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/3WNxdumkSMGMJRhEgK80qx'},
#                                 'href': 'https://api.spotify.com/v1/albums/3WNxdumkSMGMJRhEgK80qx',
#                                 'id': '3WNxdumkSMGMJRhEgK80qx',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2738e49866860c25afffe2f1a02',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e028e49866860c25afffe2f1a02',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048518e49866860c25afffe2f1a02',
#                                             'width': 64}],
#                                 'name': '...Baby One More Time (Digital Deluxe '
#                                         'Version)',
#                                 'release_date': '1999-01-12',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 16,
#                                 'type': 'album',
# ...
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b27361ffafd5e31a37336531cf95',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e0261ffafd5e31a37336531cf95',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000485161ffafd5e31a37336531cf95',
#                                             'width': 64}],
#                                 'name': 'Fanmail',
#                                 'release_date': '1999-02-23',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 17,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1CvjjpvqVMoyprsf74bpYW'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0TImkz4nPqjegtVSMZnMRq'},
#                                    'href': 'https://api.spotify.com/v1/artists/0TImkz4nPqjegtVSMZnMRq',
#                                    'id': '0TImkz4nPqjegtVSMZnMRq',
#                                    'name': 'TLC',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:0TImkz4nPqjegtVSMZnMRq'}],
#                       'disc_number': 1,
#                       'duration_ms': 214400,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USLF29900479'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/1KGi9sZVMeszgZOWivFpxs'},
#                       'href': 'https://api.spotify.com/v1/tracks/1KGi9sZVMeszgZOWivFpxs',
#                       'id': '1KGi9sZVMeszgZOWivFpxs',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'No Scrubs',
#                       'popularity': 81,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/69daa711bddd8fe7aa9acf17106ca85cf1ccfa14?cid=acf6602caa5749f79900cabb94c1c3e4',
#                       'track': True,
#                       'track_number': 5,
#                       'type': 'track',
#                       'uri': 'spotify:track:1KGi9sZVMeszgZOWivFpxs'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gBjLmx6zQnFGQJCAQpRgw'},
#                                              'href': 'https://api.spotify.com/v1/artists/2gBjLmx6zQnFGQJCAQpRgw',
#                                              'id': '2gBjLmx6zQnFGQJCAQpRgw',
#                                              'name': 'Nelly',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2gBjLmx6zQnFGQJCAQpRgw'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/1kh5XByhI0DDWV7m9kddr0'},
#                                 'href': 'https://api.spotify.com/v1/albums/1kh5XByhI0DDWV7m9kddr0',
#                                 'id': '1kh5XByhI0DDWV7m9kddr0',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273367bb42d6ff622f44303bae5',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02367bb42d6ff622f44303bae5',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851367bb42d6ff622f44303bae5',
#                                             'width': 64}],
#                                 'name': 'Nellyville',
#                                 'release_date': '2002-06-25',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 20,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:1kh5XByhI0DDWV7m9kddr0'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2gBjLmx6zQnFGQJCAQpRgw'},
#                                    'href': 'https://api.spotify.com/v1/artists/2gBjLmx6zQnFGQJCAQpRgw',
#                                    'id': '2gBjLmx6zQnFGQJCAQpRgw',
#                                    'name': 'Nelly',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2gBjLmx6zQnFGQJCAQpRgw'}],
#                       'disc_number': 1,
#                       'duration_ms': 228240,
#                       'episode': False,
#                       'explicit': True,
#                       'external_ids': {'isrc': 'USUR10200371'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/5FLctoy4mpCxLJ1QPneTOV'},
#                       'href': 'https://api.spotify.com/v1/tracks/5FLctoy4mpCxLJ1QPneTOV',
#                       'id': '5FLctoy4mpCxLJ1QPneTOV',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/04KTF78FFg8sOHC1BADqbY'},
#                                       'href': 'https://api.spotify.com/v1/tracks/04KTF78FFg8sOHC1BADqbY',
#                                       'id': '04KTF78FFg8sOHC1BADqbY',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:04KTF78FFg8sOHC1BADqbY'},
#                       'name': 'Hot In Herre',
#                       'popularity': 59,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 3,
#                       'type': 'track',
#                       'uri': 'spotify:track:5FLctoy4mpCxLJ1QPneTOV'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#                                              'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#                                              'id': '2NdeV5rLm47xAvogXrYhJX',
#                                              'name': 'Ciara',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/71gUhKYZIWmmjqAHlY4Br3'},
#                                 'href': 'https://api.spotify.com/v1/albums/71gUhKYZIWmmjqAHlY4Br3',
#                                 'id': '71gUhKYZIWmmjqAHlY4Br3',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b273c1e3659212de0f437bbf395e',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e02c1e3659212de0f437bbf395e',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d00004851c1e3659212de0f437bbf395e',
#                                             'width': 64}],
#                                 'name': 'Goodies',
#                                 'release_date': '2004-09-27',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 13,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:71gUhKYZIWmmjqAHlY4Br3'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2NdeV5rLm47xAvogXrYhJX'},
#                                    'href': 'https://api.spotify.com/v1/artists/2NdeV5rLm47xAvogXrYhJX',
#                                    'id': '2NdeV5rLm47xAvogXrYhJX',
#                                    'name': 'Ciara',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2NdeV5rLm47xAvogXrYhJX'},
#                                   {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wIVse2owClT7go1WT98tk'},
#                                    'href': 'https://api.spotify.com/v1/artists/2wIVse2owClT7go1WT98tk',
#                                    'id': '2wIVse2owClT7go1WT98tk',
#                                    'name': 'Missy Elliott',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2wIVse2owClT7go1WT98tk'}],
#                       'disc_number': 1,
#                       'duration_ms': 203786,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USLF20400121'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/7uKcScNXuO3MWw6LowBjW1'},
#                       'href': 'https://api.spotify.com/v1/tracks/7uKcScNXuO3MWw6LowBjW1',
#                       'id': '7uKcScNXuO3MWw6LowBjW1',
#                       'is_local': False,
#                       'is_playable': True,
#                       'name': 'One, Two Step (feat. Missy Elliott)',
#                       'popularity': 77,
#                       'preview_url': 'https://p.scdn.co/mp3-preview/ebc79c6e835bd18a744307d51c942a749e3ad2ca?cid=acf6602caa5749f79900cabb94c1c3e4',
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:7uKcScNXuO3MWw6LowBjW1'},
#             'video_thumbnail': {'url': None}},
#            {'added_at': '2016-09-09T10:44:51Z',
#             'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/22htsfsj6ksp4hr6bal4zvboa'},
#                          'href': 'https://api.spotify.com/v1/users/22htsfsj6ksp4hr6bal4zvboa',
#                          'id': '22htsfsj6ksp4hr6bal4zvboa',
#                          'type': 'user',
#                          'uri': 'spotify:user:22htsfsj6ksp4hr6bal4zvboa'},
#             'is_local': False,
#             'primary_color': None,
#             'track': {'album': {'album_type': 'album',
#                                 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#                                              'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#                                              'id': '5YGY8feqx7naU7z4HrwZM6',
#                                              'name': 'Miley Cyrus',
#                                              'type': 'artist',
#                                              'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#                                 'external_urls': {'spotify': 'https://open.spotify.com/album/0IuHVgAvbNDJnJepuSZ8Oz'},
#                                 'href': 'https://api.spotify.com/v1/albums/0IuHVgAvbNDJnJepuSZ8Oz',
#                                 'id': '0IuHVgAvbNDJnJepuSZ8Oz',
#                                 'images': [{'height': 640,
#                                             'url': 'https://i.scdn.co/image/ab67616d0000b2734ea6653890e297d53e93e3e0',
#                                             'width': 640},
#                                            {'height': 300,
#                                             'url': 'https://i.scdn.co/image/ab67616d00001e024ea6653890e297d53e93e3e0',
#                                             'width': 300},
#                                            {'height': 64,
#                                             'url': 'https://i.scdn.co/image/ab67616d000048514ea6653890e297d53e93e3e0',
#                                             'width': 64}],
#                                 'name': 'The Time Of Our Lives (International '
#                                         'Version)',
#                                 'release_date': '2009-01-01',
#                                 'release_date_precision': 'day',
#                                 'total_tracks': 8,
#                                 'type': 'album',
#                                 'uri': 'spotify:album:0IuHVgAvbNDJnJepuSZ8Oz'},
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5YGY8feqx7naU7z4HrwZM6'},
#                                    'href': 'https://api.spotify.com/v1/artists/5YGY8feqx7naU7z4HrwZM6',
#                                    'id': '5YGY8feqx7naU7z4HrwZM6',
#                                    'name': 'Miley Cyrus',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:5YGY8feqx7naU7z4HrwZM6'}],
#                       'disc_number': 1,
#                       'duration_ms': 202066,
#                       'episode': False,
#                       'explicit': False,
#                       'external_ids': {'isrc': 'USHR10924519'},
#                       'external_urls': {'spotify': 'https://open.spotify.com/track/3E7dfMvvCLUddWissuqMwr'},
#                       'href': 'https://api.spotify.com/v1/tracks/3E7dfMvvCLUddWissuqMwr',
#                       'id': '3E7dfMvvCLUddWissuqMwr',
#                       'is_local': False,
#                       'is_playable': True,
#                       'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5Q0Nhxo0l2bP3pNjpGJwV1'},
#                                       'href': 'https://api.spotify.com/v1/tracks/5Q0Nhxo0l2bP3pNjpGJwV1',
#                                       'id': '5Q0Nhxo0l2bP3pNjpGJwV1',
#                                       'type': 'track',
#                                       'uri': 'spotify:track:5Q0Nhxo0l2bP3pNjpGJwV1'},
#                       'name': 'Party In The U.S.A.',
#                       'popularity': 82,
#                       'preview_url': None,
#                       'track': True,
#                       'track_number': 2,
#                       'type': 'track',
#                       'uri': 'spotify:track:3E7dfMvvCLUddWissuqMwr'},
#             'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/2Uh5VseH92384vmM5SMUgA/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 516}

# %%
playlist['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
playlist_all[0]['track']['id'] #['items'][0]['track']["uri"])[0]
# Out:
# '0AnSLxClEuLksOSiIYHm4G'

# %%
len(playlist_all)
# Out:
# 516

# %%
list_of_songs=[]
for index in range(0,len(playlist_all)):
    list_of_songs.append(sp.audio_features(playlist_all[index]['track']['id'])[0])

# %%
list_of_songs_1 = pd.DataFrame(list_of_songs)

# %%
list_of_songs_1
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.920   0.692    7    -4.376     1       0.2110       0.07820
# 1           0.803   0.717    2    -3.956     1       0.2680       0.06440
# 2           0.648   0.931    1    -3.150     0       0.1810       0.00937
# 3           0.802   0.682    1    -5.924     0       0.2220       0.11100
# 4           0.774   0.839    5    -3.948     0       0.1140       0.02700
# ..            ...     ...  ...       ...   ...          ...           ...
# 511         0.789   0.550   11    -7.423     0       0.0473       0.17400
# 512         0.710   0.697   11    -4.758     0       0.0989       0.02540
# 513         0.823   0.879    5    -3.581     0       0.1160       0.10900
# 514         0.694   0.881    1    -4.053     0       0.0701       0.01530
# 515         0.888   0.822    5    -6.843     0       0.2190       0.00250
#
#      instrumentalness  liveness  valence    tempo            type  \
# 0            0.000000    0.1100    0.633  105.017  audio_features
# 1            0.000000    0.2480    0.582  112.963  audio_features
# 2            0.000000    0.7520    0.744  153.649  audio_features
# 3            0.000014    0.1090    0.586  123.950  audio_features
# 4            0.016600    0.2520    0.923  142.985  audio_features
# ..                ...       ...      ...      ...             ...
# 511          0.000000    0.0614    0.696  172.049  audio_features
# 512          0.000000    0.0664    0.210   98.893  audio_features
# 513          0.000000    0.1420    0.661  140.093  audio_features
# 514          0.019600    0.0851    0.924  121.554  audio_features
# 515          0.019700    0.3030    0.233  102.753  audio_features
#
#                          id                                   uri  \
# 0    0AnSLxClEuLksOSiIYHm4G  spotify:track:0AnSLxClEuLksOSiIYHm4G
# 1    1HWsZxKLgySrtXOi3a5Q0j  spotify:track:1HWsZxKLgySrtXOi3a5Q0j
# 2    2ygMBIctKIAfbEBcT9065L  spotify:track:2ygMBIctKIAfbEBcT9065L
# 3    20jYtEun4dUdYZ9foaOC48  spotify:track:20jYtEun4dUdYZ9foaOC48
# 4    26nr9XnFCYWxBTIP7HyWXg  spotify:track:26nr9XnFCYWxBTIP7HyWXg
# ..                      ...                                   ...
# 511  6c0GmyBsE7mQtrVvxJaWc3  spotify:track:6c0GmyBsE7mQtrVvxJaWc3
# 512  2DRHvVOlWg7Z3pkzn58Jrh  spotify:track:2DRHvVOlWg7Z3pkzn58Jrh
# 513  7hlwEYdoK7d0Hz7h4pGqDe  spotify:track:7hlwEYdoK7d0Hz7h4pGqDe
# 514  2He3NOyqtLNE3RQPpeDdSb  spotify:track:2He3NOyqtLNE3RQPpeDdSb
# 515  4dY4JVC0Q9CwpeZ6JAclIc  spotify:track:4dY4JVC0Q9CwpeZ6JAclIc
#
#                                             track_href  \
# 0    https://api.spotify.com/v1/tracks/0AnSLxClEuLk...
# 1    https://api.spotify.com/v1/tracks/1HWsZxKLgySr...
# 2    https://api.spotify.com/v1/tracks/2ygMBIctKIAf...
# 3    https://api.spotify.com/v1/tracks/20jYtEun4dUd...
# 4    https://api.spotify.com/v1/tracks/26nr9XnFCYWx...
# ..                                                 ...
# 511  https://api.spotify.com/v1/tracks/6c0GmyBsE7mQ...
# 512  https://api.spotify.com/v1/tracks/2DRHvVOlWg7Z...
# 513  https://api.spotify.com/v1/tracks/7hlwEYdoK7d0...
# 514  https://api.spotify.com/v1/tracks/2He3NOyqtLNE...
# 515  https://api.spotify.com/v1/tracks/4dY4JVC0Q9Cw...
#
#                                           analysis_url  duration_ms  \
# 0    https://api.spotify.com/v1/audio-analysis/0AnS...       215920
# 1    https://api.spotify.com/v1/audio-analysis/1HWs...       296187
# 2    https://api.spotify.com/v1/audio-analysis/2ygM...       213067
# 3    https://api.spotify.com/v1/audio-analysis/20jY...       326960
# 4    https://api.spotify.com/v1/audio-analysis/26nr...       198813
# ..                                                 ...          ...
# 511  https://api.spotify.com/v1/audio-analysis/6c0G...       231573
# 512  https://api.spotify.com/v1/audio-analysis/2DRH...       257867
# 513  https://api.spotify.com/v1/audio-analysis/7hlw...       223080
# 514  https://api.spotify.com/v1/audio-analysis/2He3...       231787
# 515  https://api.spotify.com/v1/audio-analysis/4dY4...       312360
#
#      time_signature
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# ..              ...
# 511               4
# 512               4
# 513               4
# 514               4
# 515               4
#
# [516 rows x 18 columns]

# %%
list_of_songs_1.to_csv("list_of_songs_1.csv")
